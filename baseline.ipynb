# %%
from gensim.models.fasttext import FastText
from gensim.models import Word2Vec
from catboost import Pool, CatBoostClassifier
import pandas as pd
import re
import pytorch_lightning as pl
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report,accuracy_score
import numpy as np

# %%
train_df = pd.read_csv("data/train_supervised_dataset.csv").fillna("")
test_df = pd.read_csv("data/test_dataset.csv")

# %%
test_df.head()
# Out:
#    id                                             name
# 0   0  469-210 ЕРМАК Клей универсальный, 15мл, блистер
# 1   1                  Торт СЛАДУШКА Зимняя вишня 700г
# 2   2             Смеситель "CALORIE" 1023 А06 д/кухни
# 3   3                                   Лимон 50гр БАР
# 4   4            Коньяк САРАДЖИШВИЛИ 5 лет 0,5л Грузия

# %%
train_df.head()
# Out:
#    id                                            name      good          brand
# 0   0         Petmax Бантик леопард с красн розой 2шт    бантик         petmax
# 1   1                87191 Бусы для елки шарики_87191      бусы
# 2   2              Футболка Piazza Italia WR011446881  футболка  piazza italia
# 3   3  7) YI572-03X-ONE ЗАКОЛКА ДЛЯ ВОЛОС ДЛЯ ДЕВОЧКИ   заколка
# 4   4                               Одежда (вес) 1500    одежда

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      25000 non-null  int64
#  1   name    25000 non-null  object
#  2   good    25000 non-null  object
#  3   brand   25000 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 781.4+ KB

# %%
nu_brand = train_df["brand"].nunique()
nu_good = train_df["good"].nunique()

print(f"Количество неуникальных брендов: {nu_brand}")
print(f"Количество неуникальных товаров: {nu_good}")
# Out:
# Количество неуникальных брендов: 6976
# Количество неуникальных товаров: 2820

# %%
# Создадим функцию очистки текста
def clean_text(text):
    text = text.lower()
    #text = re.sub(r'[^\sa-zA-Z0-9@\[\]]',' ',text) # Удаляет пунктцацию
    text = re.sub(r'\w*\d+\w*', '', text) # Удаляет цифры
    text = re.sub(r'[^\w\s]', ' ', text) # Удаляет знаки
    text = re.sub(r'\b\S{1}\b', '', text) # Удаляет слова из 1-й буквы
    text = re.sub(r'\b\S{2}\b', '', text) # Удаляет слова из 2-х букв
    text = re.sub('\s{2,}', " ", text) # Удаляет ненужные пробелы
    return text

# Применяем ее к тексту
train_df['name'] = train_df['name'].apply(clean_text)

# %%
train_df
# Out:
#           id                                               name        good  \
# 0          0                 petmax бантик леопард красн розой       бантик
# 1          1                                     бусы для елки         бусы
# 2          2                            футболка piazza italia     футболка
# 3          3                  one заколка для волос для девочки     заколка
# 4          4                                        одежда вес       одежда
# ...      ...                                                ...         ...
# 24995  24995                                       вода саирме         вода
# 24996  24996                                  моя семя ассортим
# 24997  24997              рулет бисквитн яшкино клубничный слив       рулет
# 24998  24998   почвогрунт цветочное счастье фаско декоративн...  почвогрунт
# 24999  24999              семечки жар крутой окер солью гринвич     семечки
#
#                brand
# 0             petmax
# 1
# 2      piazza italia
# 3
# 4
# ...              ...
# 24995         sairme
# 24996      моя семья
# 24997         яшкино
# 24998          фаско
# 24999    крутой окер
#
# [25000 rows x 4 columns]

# %%
train_df['br'] = train_df.apply(lambda x: x["brand"] + "ы" if(x["brand"] == 'petmax') else 1, axis=1)

# %%
train_df
# Out:
#           id                                               name        good  \
# 0          0                 petmax бантик леопард красн розой       бантик
# 1          1                                     бусы для елки         бусы
# 2          2                            футболка piazza italia     футболка
# 3          3                  one заколка для волос для девочки     заколка
# 4          4                                        одежда вес       одежда
# ...      ...                                                ...         ...
# 24995  24995                                       вода саирме         вода
# 24996  24996                                  моя семя ассортим
# 24997  24997              рулет бисквитн яшкино клубничный слив       рулет
# 24998  24998   почвогрунт цветочное счастье фаско декоративн...  почвогрунт
# 24999  24999              семечки жар крутой окер солью гринвич     семечки
#
#                brand       br
# 0             petmax  petmaxы
# 1                           1
# 2      piazza italia        1
# 3                           1
# 4                           1
# ...              ...      ...
# 24995         sairme        1
# 24996      моя семья        1
# 24997         яшкино        1
# 24998          фаско        1
# 24999    крутой окер        1
#
# [25000 rows x 5 columns]

# %%
#names = pd.concat((train_df[["name"]], test_df)).reset_index(drop=True)

# %%
train_df["tokens"] = train_df["name"].str.lower().str.split()

# %%
def apply_bio_tagging(row):
    """
    По токенам чека и разметке (то есть выделенным товарам и брендам) строим BIO-теги
    """
    tokens = row["tokens"]
    good = row["good"].split(',')[0].split()
    brand = row["brand"].split(',')[0].split()
    tags = ['O'] * len(tokens)
    for i, token in enumerate(tokens):
        if len(good) > 0 and tokens[i:i + len(good)] == good:
            tags[i] = "B-GOOD"
            for j in range(i + 1, i + len(good)):
                tags[j] = "I-GOOD"
        if len(brand) > 0 and tokens[i:i + len(brand)] == brand:
            tags[i] = "B-BRAND"
            for j in range(i + 1, i + len(brand)):
                tags[j] = "I-BRAND"
    return tags

# %%
train_df["tags"] = train_df.apply(apply_bio_tagging, axis=1)

# %%
train_df.head()
# Out:
#    id                                name      good          brand  \
# 0   0  petmax бантик леопард красн розой     бантик         petmax
# 1   1                      бусы для елки       бусы
# 2   2             футболка piazza italia   футболка  piazza italia
# 3   3   one заколка для волос для девочки   заколка
# 4   4                         одежда вес     одежда
#
#                                      tokens                        tags
# 0   [petmax, бантик, леопард, красн, розой]  [B-BRAND, B-GOOD, O, O, O]
# 1                         [бусы, для, елки]              [B-GOOD, O, O]
# 2                [футболка, piazza, italia]  [B-GOOD, B-BRAND, I-BRAND]
# 3  [one, заколка, для, волос, для, девочки]     [O, B-GOOD, O, O, O, O]
# 4                             [одежда, вес]                 [B-GOOD, O]

# %%
tags = []
for tag in train_df['tags'].to_list():
    tags.extend(tag)
print('Entities in our data set')
set(tags)
# Out:
# Entities in our data set
# {'B-BRAND', 'B-GOOD', 'I-BRAND', 'I-GOOD', 'O'}

# %%
w2v_model = FastText.load("fst.model")

# %%
words = list(w2v_model.wv.index_to_key)

# %%
words[0:10]
# Out:
# ['для',
#  'черный',
#  'напиток',
#  'белый',
#  'пиво',
#  'набор',
#  'арт',
#  'вода',
#  'сыр',
#  'бзмж']

# %%
def to_series(column):
    token_list = column.to_list()
    flat_list = [item for sublist in token_list for item in sublist]
    tokens_series = pd.Series(flat_list)
    return tokens_series

# %%
def make_datasets(data):
    tags = to_series(train_df["tags"])
    tokenss = to_series(train_df["tokens"])
    dataset = tokenss.apply(lambda x: w2v_model.wv.word_vec(x))
    dtv_train = pd.concat([pd.DataFrame(dataset.to_list()), 
           pd.DataFrame(tags)], axis=1, ignore_index=True)
    dtv_train.rename(columns={300:"labels"}, inplace=True)

    good_train = dtv_train.loc[dtv_train['labels'].isin(["B-GOOD", "I-GOOD", "O"])]
    brand_train = dtv_train.loc[dtv_train['labels'].isin(["B-BRAND", "I-BRAND", "O"])]
    
    
    return good_train, brand_train

# %%
good_train, brand_train = make_datasets(train_df)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9880\4192646330.py:4: DeprecationWarning: Call to deprecated `word_vec` (Use get_vector instead).
#   dataset = tokenss.apply(lambda x: w2v_model.wv.word_vec(x))

# %%
good_train.head()
# Out:
#           0         1         2         3         4         5         6  \
# 1 -0.315531 -0.481765 -0.652540  0.463447 -0.122203 -0.480863 -0.137293
# 2  0.016791 -0.180934 -0.818971 -0.219705  0.090976  0.283494 -0.335978
# 3 -0.534205  0.190236 -0.244919 -0.081599 -0.028301 -0.480327 -0.667193
# 4 -0.615371  0.064413 -0.611597 -0.213545 -0.000231 -0.084669 -0.125738
# 5 -0.039074  0.198955  0.123389  0.595596 -0.388866 -0.281300 -0.065837
#
#           7         8         9  ...       291       292       293       294  \
# 1 -0.003325 -0.419353 -0.667099  ...  0.288909 -0.260036 -0.304667  0.510278
# 2 -0.051116  0.031835  0.027362  ... -0.045046 -0.294219 -0.170586 -0.594982
# 3  0.762960  0.306905 -0.337797  ... -0.062866 -0.007137  0.465703 -0.371900
# 4 -0.710554  0.326323  0.214496  ...  0.571753 -0.572989  0.273390 -0.057201
# 5  0.157076 -0.674399 -0.681910  ...  0.502278 -0.383531  0.193589 -0.285847
#
#         295       296       297       298       299  labels
# 1 -0.332718 -0.203781  0.333719 -0.382257  0.286850  B-GOOD
# 2  0.060734  0.167994  0.199121 -0.111107  0.212782       O
# 3 -0.231565  0.074749  0.122957  0.204606  0.577125       O
# 4 -0.458437  0.784217  0.139628 -0.054242 -0.579743       O
# 5  0.329078  0.393911  0.632338 -0.315968 -0.144979  B-GOOD
#
# [5 rows x 301 columns]

# %%
'''
bb_sum = dtv_train[dtv_train["labels"] == "B-GOOD"]
bb = bb_sum["labels"].value_counts()

bi_sum = dtv_train[dtv_train["labels"] == "I-GOOD"]
bi = bi_sum["labels"].value_counts()

o_sum = dtv_train[dtv_train["labels"] == "O"]
o = o_sum["labels"].value_counts()

print(f"B_BRAND: {bb}")
print(f"I_BRAND: {bi}")
print(f"O: {o}")
'''
# Out:
# '\nbb_sum = dtv_train[dtv_train["labels"] == "B-GOOD"]\nbb = bb_sum["labels"].value_counts()\n\nbi_sum = dtv_train[dtv_train["labels"] == "I-GOOD"]\nbi = bi_sum["labels"].value_counts()\n\no_sum = dtv_train[dtv_train["labels"] == "O"]\no = o_sum["labels"].value_counts()\n\nprint(f"B_BRAND: {bb}")\nprint(f"I_BRAND: {bi}")\nprint(f"O: {o}")\n'

# %%
#dataframe = dtv_train.reset_index(drop=True)

# %%
catboost_params = {
    "learning_rate": 0.035, 
    "n_estimators": 4000, 
    "subsample": 0.075, 
    "max_depth": 6,
    "l2_leaf_reg": 40,
    'task_type': 'GPU',
    'use_best_model': True,
    "verbose": 100,
    #class_weights = class_weights,
    "eval_metric":'TotalF1',
    "bootstrap_type": "Bernoulli",
    "loss_function": 'MultiClass'
    }

# %%
def modeling(good_ds, brand_ds, **catboost_params):
    X_good = good_ds.drop("labels", axis=1)
    y_good = good_ds.labels

    X_brand = brand_ds.drop("labels", axis=1)
    y_brand = brand_ds.labels

    X_train_g, X_test_g, y_train_g, y_test_g = train_test_split(X_good, y_good, test_size=0.20)
    X_train_b, X_test_b, y_train_b, y_test_b = train_test_split(X_brand, y_brand, test_size=0.20)

    train_dataset_g = Pool(data=X_train_g,
                    label=y_train_g)

    eval_dataset_g = Pool(data=X_test_g,
                    label=y_test_g)
    
    train_dataset_b = Pool(data=X_train_b,
                    label=y_train_b)

    eval_dataset_b = Pool(data=X_test_b,
                    label=y_test_b)
    
    model_good = CatBoostClassifier(**catboost_params)
    model_brand = CatBoostClassifier(**catboost_params)

    model_good.fit(train_dataset_g, eval_set=eval_dataset_g)
    model_brand.fit(train_dataset_b, eval_set=eval_dataset_b)

    pred_good = model_good.predict(X_test_g)
    pred_brand = model_brand.predict(X_test_b)

    return pred_good, y_test_g, pred_brand, y_test_b, model_good, model_brand

# %%
pred_good, y_test_g, pred_brand, y_test_b, model_good, model_brand = modeling(good_train, brand_train)
# Out:
# Learning rate set to 0.117502
# 0:	learn: 0.9877273	test: 0.9880601	best: 0.9880601 (0)	total: 241ms	remaining: 4m
# 1:	learn: 0.9019761	test: 0.9024980	best: 0.9024980 (1)	total: 405ms	remaining: 3m 22s
# 2:	learn: 0.8321732	test: 0.8333702	best: 0.8333702 (2)	total: 558ms	remaining: 3m 5s
# 3:	learn: 0.7746585	test: 0.7760567	best: 0.7760567 (3)	total: 724ms	remaining: 3m
# 4:	learn: 0.7280938	test: 0.7296577	best: 0.7296577 (4)	total: 881ms	remaining: 2m 55s
# 5:	learn: 0.6876252	test: 0.6897444	best: 0.6897444 (5)	total: 1.05s	remaining: 2m 53s
# 6:	learn: 0.6517312	test: 0.6537247	best: 0.6537247 (6)	total: 1.2s	remaining: 2m 50s
# 7:	learn: 0.6219734	test: 0.6241312	best: 0.6241312 (7)	total: 1.36s	remaining: 2m 48s
# 8:	learn: 0.5950112	test: 0.5976997	best: 0.5976997 (8)	total: 1.51s	remaining: 2m 46s
# 9:	learn: 0.5713242	test: 0.5743147	best: 0.5743147 (9)	total: 1.65s	remaining: 2m 43s
# 10:	learn: 0.5514158	test: 0.5545168	best: 0.5545168 (10)	total: 1.79s	remaining: 2m 40s
# 11:	learn: 0.5319833	test: 0.5351267	best: 0.5351267 (11)	total: 1.94s	remaining: 2m 39s
# 12:	learn: 0.5143528	test: 0.5174888	best: 0.5174888 (12)	total: 2.1s	remaining: 2m 39s
# 13:	learn: 0.4983674	test: 0.5016552	best: 0.5016552 (13)	total: 2.26s	remaining: 2m 39s
# 14:	learn: 0.4843838	test: 0.4879568	best: 0.4879568 (14)	total: 2.41s	remaining: 2m 38s
# 997:	learn: 0.1745783	test: 0.2517008	best: 0.2516862 (995)	total: 2m 4s	remaining: 250ms
# 998:	learn: 0.1745498	test: 0.2517105	best: 0.2516862 (995)	total: 2m 4s	remaining: 125ms
# 999:	learn: 0.1744923	test: 0.2517050	best: 0.2516862 (995)	total: 2m 4s	remaining: 0us
#
# bestTest = 0.2516862077
# bestIteration = 995
#
# Shrink model to first 996 iterations.

# %%
'''
classes = np.unique(y)
weights = compute_class_weight(class_weight='balanced', classes=classes, y=y)
class_weights = dict(zip(classes, weights))
class_weights
'''
# Out:
# "\nclasses = np.unique(y)\nweights = compute_class_weight(class_weight='balanced', classes=classes, y=y)\nclass_weights = dict(zip(classes, weights))\nclass_weights\n"

# %%
print(classification_report(y_test_g,pred_good))
# Out:
#               precision    recall  f1-score   support
#
#       B-GOOD       0.90      0.88      0.89      4553
#       I-GOOD       0.32      0.09      0.14        66
#            O       0.95      0.96      0.96     12516
#
#     accuracy                           0.94     17135
#    macro avg       0.72      0.64      0.66     17135
# weighted avg       0.94      0.94      0.94     17135

# %%
print(classification_report(y_test_b, pred_brand))
# Out:
#               precision    recall  f1-score   support
#
#      B-BRAND       0.83      0.70      0.76      2720
#      I-BRAND       0.70      0.40      0.51       445
#            O       0.92      0.97      0.94     12541
#
#     accuracy                           0.91     15706
#    macro avg       0.82      0.69      0.74     15706
# weighted avg       0.90      0.91      0.90     15706

# %%
test_df = pd.read_csv("data/test_dataset.csv")
sub_df = pd.read_csv("data/sample_submission.csv")

# %%
test_df
# Out:
#         id                                             name
# 0        0  469-210 ЕРМАК Клей универсальный, 15мл, блистер
# 1        1                  Торт СЛАДУШКА Зимняя вишня 700г
# 2        2             Смеситель "CALORIE" 1023 А06 д/кухни
# 3        3                                   Лимон 50гр БАР
# 4        4            Коньяк САРАДЖИШВИЛИ 5 лет 0,5л Грузия
# ...    ...                                              ...
# 4995  4995                      774352 Рамка 2П., сл. кость
# 4996  4996                    Энерг. напиток Red Bull 0.25л
# 4997  4997                36/025 Наконечники (т. никель) шт
# 4998  4998      Шоколад РиттерСпорт мол.с цел.миндалем 100г
# 4999  4999                       00264242 Опора шаровая L=R
#
# [5000 rows x 2 columns]

# %%
sub_df
# Out:
#         id           good          brand
# 0        0  товар1,товар2  бренд1,бренд2
# 1        1          товар          бренд
# 2        2            NaN            NaN
# 3        3            NaN            NaN
# 4        4            NaN            NaN
# ...    ...            ...            ...
# 4995  4995            NaN            NaN
# 4996  4996            NaN            NaN
# 4997  4997            NaN            NaN
# 4998  4998            NaN            NaN
# 4999  4999            NaN            NaN
#
# [5000 rows x 3 columns]

# %%
test_df['name'] = test_df['name'].apply(clean_text)

# %%
test_df.head()
# Out:
#    id                               name
# 0   0   ермак клей универсальный блистер
# 1   1        торт сладушка зимняя вишня
# 2   2            смеситель calorie кухни
# 3   3                          лимон бар
# 4   4     коньяк сараджишвили лет грузия

# %%
test_df["tokens"] = test_df["name"].str.lower().str.split()

# %%
test_df.head()
# Out:
#    id                               name  \
# 0   0   ермак клей универсальный блистер
# 1   1        торт сладушка зимняя вишня
# 2   2            смеситель calorie кухни
# 3   3                          лимон бар
# 4   4     коньяк сараджишвили лет грузия
#
#                                   tokens
# 0  [ермак, клей, универсальный, блистер]
# 1        [торт, сладушка, зимняя, вишня]
# 2            [смеситель, calorie, кухни]
# 3                           [лимон, бар]
# 4    [коньяк, сараджишвили, лет, грузия]

# %%
test_df.to_csv("test.csv")

# %%
def subm_good(x):
    B_G = []
    I_G = []
    
    count = 0
    for i in range(len(x["tokens"]) - 1):
        if count == 0 and (x["results"][i] == "B-GOOD"):
            B_G.append(x['tokens'][i])
            I_G.append("")
            count+=1
            
        elif str(x["results"][i]) == "I-GOOD":
            I_G.append(" " + x['tokens'][i])
            B_G.append("")

    print(B_G)
    df = pd.DataFrame({"b": B_G, "i": I_G})
    df["good"] = df["b"] + df["i"]
    s = df["good"].to_list()
    
    return "".join(s)

# %%
def subm_brand(x):
    B_B = []
    I_B = []

    count=0
    for i in range(len(x["tokens"]) - 1):
        if x["results"][i] == "B-BRAND" and count == 0:
            B_B.append(x['tokens'][i])
            I_B.append("")
            count+=1
        elif str(x["results"][i]) == "I-BRAND":
            I_B.append(" " + x['tokens'][i])
            B_B.append("")

    df = pd.DataFrame({"b": B_B, "i": I_B})
    df["brand"] = df["b"] + df["i"]
    s = df["brand"].to_list()
    
    return "".join(s)

# %%
def submission_good(test_df):
    results = []


    tokenss = to_series(test_df["tokens"])
    dataset = tokenss.apply(lambda x: w2v_model.wv.word_vec(x))
    dtv = pd.DataFrame(dataset.to_list())
    pred = model_good.predict(dtv)
    test_df['len'] = test_df["tokens"].apply(lambda x: len(x))
    
    pr = pred.copy()
    for i in range(len(test_df["len"])):
        results.append(pr[:test_df["len"][i]].flatten().tolist())
        idx = int(test_df["len"][i])
        pr =  pr[idx:]

    test_df["results"] = results 
    test_df["good"] = test_df.apply(lambda x: subm_good(x), axis=1)

    return test_df["good"]

# %%
def submission_brand(test_df):
    results = []


    tokenss = to_series(test_df["tokens"])
    dataset = tokenss.apply(lambda x: w2v_model.wv.word_vec(x))
    dtv = pd.DataFrame(dataset.to_list())
    pred = model_brand.predict(dtv)
    test_df['len'] = test_df["tokens"].apply(lambda x: len(x))
    
    pr = pred.copy()
    for i in range(len(test_df["len"])):
        results.append(pr[:test_df["len"][i]].flatten().tolist())
        idx = int(test_df["len"][i])
        pr =  pr[idx:]

    test_df["results"] = results 
    test_df["brand"] = test_df.apply(lambda x: subm_brand(x), axis=1)

    return test_df["brand"]

# %%
good = submission_good(test_df)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9880\174375647.py:6: DeprecationWarning: Call to deprecated `word_vec` (Use get_vector instead).
#   dataset = tokenss.apply(lambda x: w2v_model.wv.word_vec(x))
# ['клей']
# ['торт']
# ['смеситель']
# []
# ['коньяк']
# ['пластина']
# ['рис']
# ['труба']
# ['консервы']
# ['одеяло']
# []
# ['пюре']
# ['сироп']
# ['крем']
# []
# []
# []
# []
# ['чипсы']
# ['трусы']
# ['леденцы']
# ['печенье']
# ['майонез']
# ['штукатурка']
# ['шайба']
# ['корм']
# ['саморез']
# ['томаты']
# ['саморез']
# []
# ['держатель']
# ['рюкзак']
# ['джинсы']
# ['консервы']
# []
# ['сок']
# ['куртка']
# ['серьги']
# ['пельмени']
# ['джеггинсы']
# []
# ['фильтр']
# []
# []
# ['платье']
# ['футболка']
# []
# ['антенна']
# ['болт']
# ['линолеум']
# ['болт']
# ['коврик']
# ['пиво']
# ['тархун']
# ['пенал']
# ['ремень']
# ['футболка']
# ['шоколад']
# ['молоко']
# []
# []
# []
# ['диск', '']
# ['рюкзак']
# []
# ['дезодорант']
# ['болт']
# []
# []
# ['огурцы']
# ['молоко']
# ['футболка']
# ['арахис']
# ['пленка']
# ['арахис']
# []
# ['лимонад']
# ['мармелад']
# []
# ['опора']
# ['молоко']
# ['конфеты']
# ['крем']
# ['напиток']
# ['соус']
# []
# ['одеяло']
# []
# ['носки']
# ['перец']
# ['сумка']
# ['адаптер']
# ['шприц']
# ['саморез']
# ['печенье']
# []
# ['мармелад']
# ['сок']
# ['вино']
# ['саморез']
# ['майонез']
# ['саморез']
# ['пряники']
# ['батончик']
# []
# ['гель']
# []
# ['цепь']
# []
# ['крем']
# ['перчатки']
# ['штаны']
# ['краска']
# ['юбка']
# ['колбаса']
# ['корзина']
# ['футболка']
# ['герметик']
# []
# ['футболка']
# []
# ['носки']
# ['кофе']
# ['сайра']
# ['маслины']
# []
# ['палочки']
# ['коврик']
# ['болт']
# ['удлинитель']
# ['соус']
# ['попкорн']
# ['зефир']
# []
# []
# ['настойка']
# ['напиток']
# ['водка']
# ['перчатки']
# ['конфеты']
# ['арахис']
# []
# []
# ['икра']
# ['батон']
# ['модель']
# ['герметик']
# ['прокладки']
# ['спрей']
# ['хлеб']
# []
# ['скумбрия']
# ['фильтр']
# ['носки']
# ['пластырь']
# ['миска']
# []
# ['пакет']
# ['творог']
# ['пальто']
# ['шампунь']
# ['кофе']
# []
# []
# ['сырок']
# []
# ['муфта']
# ['подследники']
# ['попкорн']
# ['лента']
# ['икра']
# []
# []
# ['футболка']
# ['босоножки']
# ['трусы']
# ['саморез']
# ['штаны']
# ['палочки']
# ['бальзам']
# ['фреза']
# []
# []
# ['фильтр']
# []
# ['куртка']
# []
# []
# []
# ['шайба']
# ['футболка']
# ['плитка']
# []
# ['пальто']
# ['угольник']
# ['прокладки']
# ['напиток']
# ['леденцы']
# ['болт']
# []
# ['нектар']
# ['альбом']
# ['лапша']
# ['резинка']
# ['болт']
# []
# []
# ['дрожжи']
# ['мыло']
# ['крекер']
# []
# ['сабо']
# ['конфеты']
# []
# ['футболка']
# ['лампа']
# []
# []
# []
# ['лампа']
# ['обувь']
# ['пиво']
# ['фильтр']
# ['батон']
# []
# ['вафли']
# ['водка']
# []
# ['чистящее']
# ['пазл']
# ['краска']
# ['гель']
# []
# ['кружка']
# ['коктейль']
# []
# []
# ['джемпер']
# ['аскорбиновая']
# ['тетрадь']
# ['муфта']
# []
# []
# ['футболка']
# []
# ['саморез']
# ['сметана']
# ['салат']
# ['батарейка']
# ['саморез']
# ['футболка']
# ['пальто']
# ['зубная']
# ['квас']
# []
# ['краска']
# ['сандалеты']
# ['носки']
# ['наклейка']
# ['холст']
# ['футболка']
# []
# []
# []
# ['напиток']
# ['цепь']
# []
# ['контейнер']
# []
# ['вода']
# []
# ['конфеты']
# ['сухарики']
# []
# ['соус']
# ['печенье']
# []
# ['лосьон']
# ['носки']
# ['молоток']
# []
# []
# ['напиток']
# ['порошок']
# []
# []
# ['гель']
# []
# ['пластырь']
# []
# ['сок']
# []
# []
# []
# []
# ['пельмени']
# ['чай']
# ['плита']
# ['лапша']
# []
# []
# ['конфеты']
# ['пакеты']
# ['линзы']
# ['вырезка']
# ['лопата']
# []
# ['лосины']
# []
# []
# ['пена']
# []
# ['футболка']
# ['лента']
# ['палочки']
# ['пиво']
# []
# ['кастрюля']
# []
# ['джем']
# ['обувь']
# ['лимонад']
# ['пуговица']
# ['ремень']
# []
# ['семечки']
# ['футболка']
# ['брюки']
# []
# []
# []
# []
# []
# ['водка']
# ['настойка']
# ['вино']
# ['футболка']
# ['заглушка']
# ['молочко']
# ['щипцы']
# []
# []
# ['капли']
# ['зефир']
# ['худи']
# ['благовония']
# ['удлинитель']
# []
# ['куртка']
# ['пластырь']
# ['папка']
# ['футболка']
# ['миксер']
# ['скотч']
# []
# []
# ['сандалии']
# []
# ['зеркало']
# ['бумага']
# ['ручка']
# []
# ['лампа']
# ['дезодорант']
# ['мыло']
# ['нектар']
# []
# ['лимонад']
# []
# ['маркер']
# ['болт']
# ['текила']
# []
# ['яйцо']
# ['пиво']
# []
# ['halls']
# ['бур']
# ['корм']
# ['болт']
# []
# []
# ['ремень']
# ['творог']
# []
# []
# ['коврик']
# []
# ['муфта']
# ['соус']
# []
# ['шайба']
# []
# ['гель']
# []
# ['футболка']
# ['пиво']
# ['карандаш']
# ['кольцо']
# ['кофта']
# []
# ['пена']
# []
# ['сухарики']
# ['пакеты']
# []
# ['футболка']
# []
# ['обувь']
# []
# []
# ['рюкзак']
# []
# ['босоножки']
# ['топ']
# ['приманка']
# []
# ['рюкзак']
# ['ветровка']
# []
# ['бальзам']
# ['хлебцы']
# ['пальто']
# ['кабель']
# []
# ['юбка']
# ['салфетки']
# ['футболка']
# ['саморез']
# ['киш']
# ['чехол']
# ['палочки']
# ['носки']
# ['молоко']
# ['напиток']
# ['муфта']
# ['брошь']
# ['лимонад']
# ['ром']
# ['бита']
# []
# []
# ['вино']
# ['кофе']
# []
# []
# ['соединитель']
# []
# []
# []
# ['футболка']
# ['футболка']
# ['сок']
# ['шампунь']
# ['ананасы']
# ['коврик']
# []
# ['куртка']
# ['фильтр']
# []
# ['сайлентблок']
# ['творог']
# ['лепешка']
# ['ремень']
# ['рис']
# []
# ['футболка']
# ['футболка']
# ['шапка']
# ['ботинки']
# []
# ['боди']
# ['лимонад']
# ['коврик']
# ['носки']
# ['сок']
# ['джинсы']
# []
# ['футболка']
# ['резинка']
# ['бур']
# ['сидр']
# []
# ['босоножки']
# ['семечки']
# ['герметик']
# ['нож']
# []
# ['альбом']
# ['свечи']
# ['каша']
# ['скатерть']
# []
# ['пиво']
# ['саморез']
# []
# []
# []
# ['труба']
# []
# ['ветровка']
# ['мышь']
# ['вода']
# ['крем']
# ['крем']
# ['лампа']
# ['пельмени']
# ['сок']
# ['гайка']
# []
# []
# ['салфетки']
# ['жаркое']
# ['футболка']
# ['крекер']
# ['творог']
# ['радиатор']
# ['мазь']
# []
# ['фильтр']
# ['редис']
# ['маска']
# ['суп']
# ['горбуша']
# ['футболка']
# ['вода']
# ['саморез']
# ['лампа']
# ['вафли']
# ['шампунь']
# ['пиво']
# ['муфта']
# ['шейка']
# ['резинка']
# ['корм']
# ['сигареты']
# ['покрывало']
# []
# []
# ['обувь']
# ['ботинки']
# []
# ['болт']
# ['нектар']
# []
# ['ножницы']
# ['плитка']
# []
# ['поло']
# ['линзы']
# ['толстовка']
# ['зеркало']
# ['сыр']
# ['саморезы']
# []
# ['ручка']
# []
# ['вентилятор']
# ['бумага']
# []
# ['каша']
# []
# ['ботинки']
# []
# []
# ['игрушка']
# ['розетка']
# []
# ['леденцы']
# ['ластик']
# []
# ['болт']
# ['пиво']
# ['зеркало']
# ['водка']
# []
# ['дезодорант']
# ['герметик']
# ['кофе']
# ['шоколад']
# ['спрей']
# []
# []
# []
# []
# ['коньяк']
# []
# []
# ['кофе']
# ['леденцы']
# []
# []
# []
# []
# ['драже']
# []
# ['батон']
# ['ботинки']
# ['колбаса']
# ['шоколад']
# ['пальто']
# []
# []
# []
# ['болт']
# ['шуруп']
# ['сифон']
# []
# ['батон']
# ['лопата']
# ['шоколад']
# ['биотворог']
# ['батончик']
# ['ботинки']
# ['крем']
# ['выключатель']
# []
# ['футболка']
# []
# []
# ['карандаш']
# ['пастилки']
# []
# ['гель']
# ['каша']
# ['майка']
# ['штаны']
# []
# ['сандалии']
# []
# ['футболка']
# ['сырок']
# []
# ['скраб']
# ['бархатцы']
# []
# ['гренки']
# ['футболка']
# []
# ['ботинки']
# ['вино']
# ['сосиски']
# ['скатерть']
# ['заглушка']
# ['шапка']
# ['сверло']
# ['колбаса']
# ['батончик']
# []
# []
# []
# ['гренки']
# ['удобрение']
# ['резинка']
# ['коктейль']
# ['пельмени']
# ['мыло']
# ['фуфайка']
# []
# []
# ['зубная']
# ['лампа']
# ['лосины']
# ['попкорн']
# ['футболка']
# ['футболка']
# ['прокладки']
# ['платье']
# []
# []
# []
# []
# ['пенал']
# []
# ['удобрение']
# ['ботинки']
# ['вино']
# []
# []
# []
# ['ботинки']
# ['саморез']
# ['чипсы']
# []
# ['контейнер']
# []
# ['скумбрия']
# []
# ['пена']
# []
# ['мороженое']
# []
# []
# ['футболка']
# ['пюре']
# ['масло']
# []
# []
# []
# ['паста']
# []
# ['эмаль']
# []
# ['хлебцы']
# ['наполнитель']
# ['бумага']
# []
# ['хлеб']
# ['босоножки']
# []
# []
# []
# []
# []
# []
# ['дезодорант']
# []
# ['ремень']
# ['печень']
# ['сухарики']
# ['гуашь']
# ['майонез']
# ['перец']
# ['герметик']
# ['фильтр']
# ['пюре']
# ['наушники']
# ['сыр']
# ['переключатель']
# []
# []
# []
# ['рюкзак']
# []
# ['томат']
# ['угольник']
# ['мороженое']
# []
# ['грунт']
# ['']
# []
# ['мороженое']
# ['рубашка']
# ['кепка']
# ['футболка']
# ['конфеты']
# ['корм']
# ['картофель']
# []
# ['щетка']
# ['вода']
# ['тарелка']
# []
# ['щупальца']
# ['фильтр']
# ['хлопья']
# []
# []
# []
# ['футболка']
# ['шорты']
# ['саморез']
# ['кеды']
# ['уголок']
# ['ботинки']
# ['вода']
# ['зубная']
# []
# ['ножовка']
# ['напиток']
# ['футболка']
# ['опора']
# []
# ['лампа']
# ['клей']
# ['футболка']
# []
# []
# ['папка']
# []
# ['щупальца']
# ['коньяк']
# []
# []
# ['шампунь']
# ['переходник']
# ['клей']
# ['леденцы']
# ['футболка']
# ['батончик']
# []
# ['приправа']
# ['футболка']
# ['слайдер']
# []
# ['мармелад']
# []
# ['футболка']
# ['джемпер']
# ['лимонад']
# []
# []
# ['держатель']
# []
# []
# []
# ['паста']
# []
# []
# ['мороженое']
# []
# ['макароны']
# ['краска']
# []
# ['форма']
# ['футболка']
# ['игрушка']
# ['шайба']
# ['грудинка']
# ['соус']
# ['патчи']
# ['линза']
# []
# ['яйцо']
# []
# []
# []
# ['напиток']
# []
# []
# ['решетка']
# ['вода']
# []
# ['кетчуп']
# []
# ['штаны']
# []
# ['арахис']
# ['чехол']
# ['фильтр']
# []
# ['']
# ['заглушка']
# ['пленка']
# []
# ['линза']
# []
# ['футболка']
# []
# ['пельмени']
# ['печенье']
# ['автошина']
# []
# ['макароны']
# []
# ['брюки']
# ['фильтр']
# ['саморез']
# ['маска']
# ['блины']
# []
# ['колбаса']
# ['шкаф']
# ['колодка']
# ['тарелка']
# ['зефир']
# ['сигареты']
# ['майонез']
# ['бархатцы']
# ['лимонад']
# []
# []
# ['помада']
# []
# ['фильтр']
# ['нектар']
# ['рюкзак']
# ['пиджак']
# []
# ['футболка']
# []
# []
# []
# ['футболка']
# ['скумбрия']
# ['саморез']
# ['пьет']
# ['шампунь']
# []
# ['куртка']
# ['кофе']
# []
# ['гель']
# ['конфеты']
# ['коктейль']
# ['эмаль']
# []
# []
# ['напиток']
# ['уголок']
# ['брюки']
# []
# []
# ['удлинитель']
# ['саморез']
# []
# []
# ['молоко']
# []
# []
# ['скумбрия']
# ['вино']
# []
# ['сумка']
# ['клей']
# ['зефир']
# ['снеки']
# ['саморез']
# ['журнал']
# []
# ['мука']
# ['рюкзак']
# []
# ['платье']
# ['ботинки']
# ['туфли']
# ['печенье']
# []
# ['ботинки']
# ['прокладки']
# ['скумбрия']
# ['раскраска']
# []
# []
# ['полуботинки']
# []
# []
# ['резинка']
# ['жевательная']
# ['футболка']
# ['соус']
# []
# []
# ['напиток']
# []
# ['футболка']
# ['фреза']
# ['зубная']
# ['шампунь']
# ['молоко']
# ['очки']
# []
# ['семечки']
# ['вода']
# ['морс']
# []
# []
# ['ролл']
# []
# ['соус']
# []
# ['паста']
# []
# ['держатель']
# []
# ['фильтр']
# []
# ['сарафан']
# ['пастила']
# ['ремень']
# ['матрас']
# ['колодка']
# ['саморез']
# ['вино']
# ['куртка']
# ['грунт']
# ['зеркало']
# ['вода']
# []
# ['ремень']
# ['зефир']
# ['футболка']
# []
# ['сок']
# ['виски']
# ['масло']
# ['печенье']
# ['семечки']
# []
# []
# ['молоко']
# ['кабель']
# ['болт']
# []
# ['болт']
# ['сахар']
# []
# ['напиток']
# ['футболка']
# []
# ['треска']
# ['водка']
# []
# ['шпатлевка']
# ['колготки']
# []
# ['футболка']
# []
# []
# []
# ['фасоль']
# ['кисть']
# ['трос']
# []
# []
# ['шуруп']
# ['фильтр']
# []
# ['футболка']
# ['саморез']
# ['шоколад']
# []
# ['бинт']
# ['каша']
# ['футболка']
# ['худи']
# ['тетрадь']
# ['сковорода']
# []
# ['яйцо']
# ['кольцо']
# ['муфта']
# ['джинсы']
# []
# ['напиток']
# []
# ['кофе']
# ['тетрадь']
# ['бисер']
# ['пирог']
# ['батончик']
# ['форма']
# []
# []
# ['карандаши']
# ['футболка']
# ['печенье']
# ['шпатлевка']
# []
# ['адаптер']
# ['фуфайка']
# ['лампочки']
# ['майонез']
# []
# ['сыр']
# ['ботинки']
# ['наклейки']
# ['вагонка']
# ['шапка']
# ['туфли']
# ['пиво']
# ['футболка']
# []
# ['пластырь']
# []
# ['ремень']
# ['йогурт']
# []
# []
# ['драже']
# ['миксер']
# ['держатель']
# ['сумка']
# ['лосины']
# ['контейнер']
# ['масло']
# ['пюре']
# []
# []
# []
# ['вода']
# []
# []
# ['маркер']
# ['сливки']
# ['шуруп']
# ['цепь']
# ['батон']
# ['футболка']
# []
# ['луковые']
# []
# []
# ['краска']
# ['лимонад']
# []
# []
# ['вода']
# ['напиток']
# ['ботинки']
# ['футболка']
# []
# []
# ['джемпер']
# []
# []
# []
# ['кабель']
# ['футболка']
# []
# ['корм']
# ['семена']
# []
# ['майка']
# []
# ['пирожное']
# ['мыло']
# ['рамка']
# ['масло']
# ['замок']
# ['пальто']
# []
# ['полироль']
# []
# []
# ['пенал']
# []
# ['пирожное']
# ['батарейки']
# ['кран']
# []
# ['гель']
# ['футболка']
# ['наполнитель']
# ['клей']
# []
# ['печенье']
# ['сухарики']
# ['полотенце']
# ['соус']
# ['гель']
# []
# ['зефир']
# ['ремень']
# []
# ['футболка']
# ['сидр']
# ['розетка']
# []
# []
# []
# ['футболка']
# ['антифриз']
# ['ластик']
# ['футболка']
# ['сухарики']
# ['снеки']
# []
# []
# ['яйцо']
# ['пельмени']
# []
# ['водка']
# ['туфли']
# []
# ['термопленка']
# ['колбаса']
# ['сосиски']
# ['макаронные', '']
# ['болт']
# ['тампоны']
# []
# ['чехол']
# ['автошины']
# ['крем']
# []
# ['крупа']
# []
# []
# ['стул']
# ['мышь']
# []
# ['шапка']
# ['футболка']
# ['чай']
# ['сосиски']
# []
# ['туфли']
# ['сумка']
# []
# ['блуза']
# ['гренки']
# []
# []
# ['лимонад']
# ['пакеты']
# ['борщ']
# ['ручка']
# ['маслины']
# ['зефир']
# ['напиток']
# ['шапка']
# ['лента']
# ['спрей']
# ['сосиски']
# ['клей']
# []
# ['вырезка']
# ['вода']
# []
# []
# ['лонгслив']
# ['пельмени']
# ['чипсы']
# ['майонез']
# ['полотенца']
# []
# []
# ['изолента']
# ['табак']
# []
# ['кастрюля']
# ['пряники']
# ['кондиционер']
# ['скатерть']
# []
# ['мастика']
# ['зефир']
# []
# ['наполнитель']
# ['корм']
# []
# ['вода']
# ['брюки']
# ['пельмени']
# ['печенье']
# []
# ['герметик']
# []
# ['игрушка']
# []
# []
# ['шоколад']
# ['конструктор']
# ['десерт']
# []
# []
# ['шампунь']
# ['резинка']
# ['сайлентблок']
# ['паста']
# ['молоко']
# ['лапша']
# []
# ['футболка']
# []
# ['саморезы']
# []
# ['саморез']
# []
# []
# ['добор']
# ['джемпер']
# ['торт']
# ['полотенце']
# ['болт']
# ['перчатки']
# ['носки']
# ['процессор']
# ['йогурт']
# ['футболка']
# []
# ['носки']
# ['корм']
# ['футболка']
# []
# ['болт']
# ['джемпер']
# ['котлеты']
# []
# ['календарь']
# ['клей']
# []
# []
# ['пюре']
# ['корм']
# ['печенье']
# ['блуза']
# ['батончик']
# []
# ['уксус']
# ['сахар']
# ['пельмени']
# ['толстовка']
# ['брошь']
# []
# ['конфета']
# []
# []
# []
# ['напиток']
# ['круассан']
# []
# []
# ['фарш']
# ['пюре']
# ['уши']
# ['тюль']
# ['пельмени']
# ['грунт']
# ['сервелат']
# ['пельмени']
# ['платочки']
# ['скатерть']
# ['держатель']
# ['ботинки']
# []
# []
# ['воблер']
# ['виски']
# ['зефир']
# ['пюре']
# ['саморез']
# ['шоколад']
# []
# ['ручка']
# []
# ['колодки']
# []
# ['пропитка']
# ['розетка']
# []
# ['розетка']
# []
# ['матрас']
# ['футболка']
# []
# ['антифриз']
# []
# ['лампа']
# ['эмаль']
# ['биточки']
# []
# ['пюре']
# ['скатерть']
# []
# ['мыло']
# ['спрей']
# []
# ['лимонад']
# ['кисть']
# ['чай']
# []
# ['колодка']
# ['сок']
# ['наушники']
# []
# []
# ['лонгслив']
# []
# ['напиток']
# []
# ['мармелад']
# ['паста']
# ['спрей']
# []
# []
# ['масло']
# ['степлер']
# ['форма']
# []
# []
# []
# ['футболка']
# ['эмаль']
# ['пиво']
# []
# ['кофе']
# ['вода']
# ['пельмени']
# ['спицы']
# ['коляска']
# ['дезодорант']
# ['свитшот']
# ['альбом']
# ['тройник']
# []
# ['лампа']
# ['аптечка']
# ['маркер']
# ['хлебцы']
# ['мыло']
# ['ботинки']
# ['кофе']
# ['пряжа']
# ['ручка']
# []
# ['ранец']
# ['носки']
# []
# ['коврик']
# ['крышка']
# ['лосины']
# ['молоко']
# ['приправа']
# ['юбка']
# ['лапша']
# []
# ['зубная']
# ['йогурт']
# ['шестерня']
# ['гирлянда']
# ['обувь']
# ['вода']
# ['футболка']
# []
# []
# ['гирлянда']
# []
# ['коктейль']
# []
# ['фуфайка']
# ['шоколад']
# ['крем']
# ['шапка']
# []
# ['ковш']
# ['штопор']
# []
# ['зажигалка']
# []
# []
# ['штаны']
# ['мороженое']
# ['сыр']
# []
# ['сухарики']
# ['билет']
# []
# ['джемпер']
# ['вино']
# []
# ['коврик']
# ['сланцы']
# ['футболка']
# ['батарейки']
# ['вино']
# []
# ['соус']
# ['семена']
# ['батончик']
# ['футболка']
# ['держатель']
# []
# ['майонез']
# []
# ['бульмени']
# ['мыло']
# []
# ['смартфон']
# ['соус']
# ['йогурт']
# ['вентилятор']
# []
# ['сыр']
# ['майонез']
# []
# []
# ['вода']
# ['заглушка']
# []
# ['краска']
# ['пряники']
# []
# ['диск', '']
# ['торт']
# []
# ['ботинки']
# ['опора']
# []
# ['напиток']
# ['скумбрия']
# ['веер']
# []
# []
# ['футболка']
# ['футболка']
# []
# []
# []
# ['саморез']
# ['кабель']
# ['замок']
# []
# ['драже']
# []
# []
# ['сок']
# ['эустома']
# ['ковш']
# ['мороженое']
# ['болт']
# []
# ['суп']
# []
# []
# ['макароны']
# ['суп']
# ['шайба']
# ['шкаф']
# ['шампунь']
# ['шайба']
# []
# ['футболка']
# []
# ['подгузники']
# []
# ['обувь']
# []
# []
# ['сок']
# ['пирог']
# ['футболка']
# ['вода']
# ['сверло']
# ['герметик']
# ['саморез']
# ['масло']
# ['нектар']
# []
# ['кувалда']
# ['ветровка']
# ['сироп']
# ['ложка']
# ['гель']
# ['футболка']
# ['футболка']
# ['пряники']
# ['книга']
# ['переходник']
# ['умывальник']
# ['жевательная']
# ['раскраска']
# ['тушь']
# ['шампунь']
# ['муфта']
# ['соус']
# ['масло']
# ['футболка']
# ['рюкзак']
# []
# []
# ['батарейка']
# []
# ['скатерть']
# ['сыр']
# []
# ['шоколад']
# []
# ['творог']
# ['контейнер']
# ['йогурт']
# ['шампунь']
# ['зефир']
# ['футболка']
# []
# []
# ['молоко']
# ['гель']
# ['футболка']
# ['пиво']
# []
# ['контейнер']
# ['розетка']
# ['сок']
# []
# []
# []
# ['кастрюля']
# ['гирлянда']
# ['резинка']
# []
# []
# []
# ['']
# ['костюм']
# ['бинт']
# []
# ['футболка']
# ['ботинки']
# []
# ['шайба']
# ['вино']
# []
# []
# []
# ['печенье']
# []
# ['кофе']
# ['сметана']
# ['кофе']
# ['пальто']
# ['батон']
# []
# ['ниппель']
# ['сметана']
# []
# ['бисер']
# ['лимонад']
# []
# ['лимонад']
# ['футболка']
# ['шампунь']
# ['пижама']
# []
# []
# ['кофе']
# []
# ['обувь']
# []
# []
# []
# ['соус']
# ['редис']
# ['пирожное']
# ['костюм']
# []
# ['обувь']
# ['шапка']
# ['сверло']
# ['опора']
# ['напиток']
# []
# ['фильтр']
# ['вино']
# ['мыло']
# []
# ['горчица']
# ['футболка']
# ['линзы']
# ['щупальца']
# ['пельмени']
# ['крем']
# []
# ['чай']
# []
# ['переключатель']
# ['палочки']
# ['футболка']
# ['соль']
# []
# []
# []
# []
# ['футболка']
# ['чайник']
# ['мыло']
# ['сумка']
# ['футболка']
# ['сумка']
# ['конфеты']
# ['фильтр']
# []
# ['футболка']
# ['пюре']
# ['контейнер']
# ['сосиски']
# ['жидкость']
# ['выключатель']
# ['арахис']
# ['пенал']
# []
# ['соус']
# []
# ['ремень']
# ['яйцо']
# ['конфеты']
# ['прокладки']
# []
# ['розетка']
# ['сыр']
# ['футболка']
# ['футболка']
# []
# ['реле']
# ['сигареты']
# []
# []
# []
# ['фисташки']
# ['печь']
# []
# []
# []
# []
# []
# ['гель']
# ['коктейль']
# ['ботинки']
# ['шорты']
# ['датчик']
# ['водка']
# ['напиток']
# ['футболка']
# ['яйцо']
# ['ботинки']
# []
# []
# []
# []
# ['табак']
# ['сапоги']
# []
# ['творог']
# ['соус']
# ['кастрюля']
# ['пирожное']
# []
# []
# ['кофе']
# ['мармелад']
# ['легинсы']
# ['ботинки']
# ['корм']
# ['пальто']
# ['джинсы']
# ['перчатки']
# ['вода']
# ['боди']
# ['кроссовки']
# []
# ['футболка']
# ['ликер']
# ['сыр']
# ['болт']
# []
# ['торт']
# []
# ['картридж']
# ['футболка']
# ['вешки']
# []
# ['саморез']
# ['удлинитель']
# []
# ['конфеты']
# ['пиво']
# []
# []
# ['вода']
# []
# ['луковые']
# ['шоколад']
# ['пластилин']
# ['пюре']
# []
# ['шорты']
# []
# []
# ['клей']
# ['фреза']
# []
# ['болт']
# ['ботинки']
# []
# ['саморез']
# ['шайба']
# []
# []
# ['пастила']
# ['уголок']
# ['печенье']
# ['линза']
# ['ботинки']
# []
# []
# ['ботинки']
# ['пиво']
# ['рюкзак']
# []
# []
# ['джинсы']
# ['футболка']
# []
# []
# ['сумка']
# ['круассаны']
# ['скумбрия']
# ['штаны']
# ['огурец']
# []
# ['болт']
# []
# ['футболка']
# ['зубная']
# []
# ['коврик']
# []
# ['тесто']
# ['масло']
# ['ремень']
# ['драже']
# ['контейнер']
# ['ручка']
# []
# ['сервелат']
# ['костюм']
# ['футболка']
# ['пряники']
# ['фильтр']
# ['часы']
# []
# ['шоколад']
# ['салат']
# []
# ['пальто']
# ['футболка']
# []
# []
# ['куртка']
# ['поплавок']
# ['носки']
# ['капли']
# ['фильтр']
# []
# ['', 'доска']
# ['переключатель']
# ['топ']
# []
# ['замок']
# ['резинка']
# ['яйцо']
# ['лента']
# []
# []
# ['молоток']
# []
# ['майка']
# ['форма']
# ['сок']
# []
# ['переходник']
# []
# []
# ['платье']
# ['платье']
# ['кофе']
# []
# ['саморез']
# ['паста']
# ['игрушка']
# ['грунтовка']
# ['футболка']
# []
# []
# ['конфеты']
# []
# []
# ['альбом']
# []
# ['замок']
# []
# ['презерватив']
# ['футболка']
# ['ремень']
# []
# []
# ['вода']
# ['линза']
# []
# ['вода']
# []
# ['футболка']
# ['шпроты']
# ['ремень']
# ['линза']
# []
# ['боди']
# ['кефир']
# []
# []
# []
# []
# ['конфеты']
# []
# []
# ['лампа']
# ['конфеты']
# ['фломастеров']
# ['процессор']
# []
# ['подводка']
# []
# ['бутсы']
# ['конфеты']
# []
# ['шайба']
# ['булочки']
# ['диск', '']
# ['футболка']
# ['прихват']
# ['толстовка']
# ['семечки']
# ['теплоизоляция']
# ['вода']
# []
# ['коврик']
# ['шайба']
# ['кофе']
# ['батарейка']
# ['грунтовка']
# ['пиво']
# []
# ['печенье']
# ['гирлянда']
# ['чай']
# []
# ['удлинитель']
# ['сухарики']
# []
# ['болт']
# ['шланг']
# []
# ['брюки']
# []
# []
# ['уголь']
# ['батарейка']
# ['попкорн']
# []
# ['творог']
# []
# ['подушечки']
# ['саморезы']
# ['угольник']
# []
# ['раскраска']
# ['гольфы']
# []
# []
# []
# []
# ['вино']
# ['напиток']
# []
# []
# []
# ['футболка']
# ['рукавица']
# ['спрей']
# ['плавки']
# ['ботинки']
# []
# []
# ['замок']
# []
# ['лимонад']
# ['брюки']
# ['суп']
# ['мойва']
# ['корм']
# ['хлеб']
# ['крем']
# ['сыворотка']
# ['мороженое']
# []
# []
# ['зубочистки']
# ['соус']
# ['напиток']
# []
# ['плинтус']
# []
# []
# ['шуруп']
# ['обувь']
# []
# ['шорты']
# []
# ['нитки', '']
# ['юбка']
# ['приправа']
# []
# ['лапша']
# ['соус']
# ['скатерть']
# ['раскраска']
# ['соус']
# ['пирог']
# ['ботинки']
# []
# ['семена']
# ['пробка']
# ['футболка']
# ['диск']
# ['овощечистка']
# ['горчица']
# ['саморез']
# ['масло']
# ['семечки']
# ['молоко']
# ['гель']
# []
# ['рис']
# ['серьги']
# ['мороженое']
# ['ремень']
# ['водолазка']
# []
# ['крючок']
# ['ботинки']
# ['настойка']
# ['крем']
# []
# ['сковорода']
# []
# ['футболка']
# ['боди']
# []
# []
# []
# ['печенье']
# ['футболка']
# ['рис']
# ['шуруп']
# ['мармелад']
# ['блуза']
# ['мыло']
# ['эмаль']
# []
# []
# ['сметана']
# ['мыло']
# []
# ['рамка']
# ['ботинки']
# []
# []
# ['шапка']
# ['икра']
# ['халва']
# ['коврик']
# ['кофе']
# ['рис']
# ['лак']
# ['хлеб']
# ['лист']
# []
# ['лампа']
# []
# ['зубная']
# ['соус']
# ['сельдь']
# ['туфли']
# ['кофе']
# ['катушка']
# []
# ['герметик']
# ['сланцы']
# ['футболка']
# ['тан']
# ['очиститель']
# ['фильтр']
# ['конфеты']
# ['карандаши']
# ['саморез']
# ['ботинки']
# ['муфта']
# ['контейнер']
# []
# ['гель']
# []
# ['одеяло']
# ['крем']
# ['фильтр']
# ['мыло']
# ['футболка']
# ['сандалии']
# ['кефир']
# ['ложка']
# ['доска']
# ['контейнер']
# ['каша']
# []
# []
# ['футболка']
# ['приправа']
# ['бульмени']
# []
# ['сырок']
# []
# []
# []
# []
# []
# ['смазка']
# ['вода']
# ['кольцо']
# ['заглушка']
# []
# []
# ['болт']
# ['вода']
# ['пакет']
# ['сушка']
# []
# ['джинсы']
# ['пуговица']
# ['лапша']
# ['хлеб']
# []
# ['футболка']
# ['футболка']
# []
# []
# []
# ['сухари']
# []
# ['сигареты']
# ['масло']
# ['цепь']
# ['носки']
# []
# []
# ['розетка']
# []
# ['бальзам']
# ['поплавок']
# ['шайба']
# ['рамка']
# ['водка']
# ['крем']
# ['колбаса']
# ['леденцы']
# []
# ['батон']
# []
# ['замок']
# []
# ['табурет']
# []
# ['кустодержатель']
# []
# []
# ['пюре']
# ['трусы']
# ['эмаль']
# ['выключатель']
# ['сухарики']
# ['бур']
# ['чипсы']
# ['табак']
# ['рюкзак']
# ['краска']
# ['нож']
# ['хлебцы']
# ['болт']
# ['конфеты']
# ['пальто']
# ['освежитель']
# ['трубка']
# []
# ['сметана']
# ['скумбрия']
# []
# ['жевательная']
# ['йогурт']
# ['рычаг']
# ['контейнер']
# []
# []
# ['футболка']
# []
# ['саморез']
# ['палочки']
# []
# ['пуговица']
# []
# ['кефир']
# ['футболка']
# []
# ['футболка']
# ['пенал']
# ['куртка']
# ['крем']
# []
# ['коньяк']
# ['кофе']
# []
# ['биойогурт']
# ['яйцо']
# ['пряники']
# ['удобрение']
# []
# []
# []
# []
# []
# []
# ['вино']
# []
# []
# ['пирог']
# ['сливки']
# ['яйцо']
# []
# []
# ['замок']
# ['заглушка']
# ['чешки']
# []
# ['гель']
# ['сигареты']
# ['контейнер']
# ['текила']
# []
# ['трубочка']
# ['кастрюля']
# []
# []
# []
# ['пиво']
# []
# []
# ['салфетки']
# ['футболка']
# []
# ['ботинки']
# ['тампоны']
# []
# ['шапка']
# ['кронштейн']
# []
# ['пельмени']
# []
# []
# []
# ['скатерть']
# ['булочка']
# ['коврик']
# ['футболка']
# ['кефир']
# []
# ['конфеты']
# ['плитка']
# ['перчатки']
# ['колодка']
# []
# []
# []
# []
# ['кофе']
# ['кольцо']
# ['вода']
# ['саморез']
# ['вино']
# []
# ['шкаф']
# ['бисер']
# ['мыло']
# ['лампа']
# ['жидкость']
# []
# ['рулетка']
# ['фильтр']
# []
# ['футболка']
# ['краска']
# []
# ['держатель']
# []
# ['батончик']
# []
# []
# []
# []
# []
# ['бассейн']
# ['штуцер']
# []
# ['печенье']
# ['пряники']
# []
# []
# ['штопор']
# ['вода']
# []
# ['йогурт']
# []
# ['бальзам']
# ['рулетка']
# []
# ['адаптер']
# ['муфта']
# ['куртка']
# ['футболка']
# []
# ['автолампа']
# ['костюм']
# ['лакомство']
# ['заглушка']
# ['вино']
# ['носки']
# ['чешки']
# ['семечки']
# ['шоколад']
# ['раковые']
# ['сыр']
# ['бальзам']
# ['футболка']
# ['крючок']
# ['пакет']
# ['адаптер']
# ['уплотнитель']
# ['конфеты']
# ['лосины']
# []
# ['ботинки']
# ['вентиль']
# []
# []
# []
# []
# ['зажим']
# ['болт']
# ['соус']
# ['резонатор']
# []
# ['рамка']
# ['книга']
# []
# ['молоко']
# ['напиток']
# []
# ['пиво']
# ['торт']
# ['тетрадь']
# ['маркер']
# ['соус']
# ['напиток']
# ['соус']
# []
# []
# ['туфли']
# ['клей']
# ['коврик']
# ['бандаж']
# ['футболка']
# ['сырок']
# []
# ['горелка']
# ['сорочка']
# ['скраб']
# ['лимонад']
# ['валик']
# []
# ['опора']
# ['настойка']
# ['пуговица']
# ['клей']
# []
# ['напиток']
# []
# ['пиво']
# ['сок']
# ['пупс']
# ['краска']
# []
# ['блины']
# ['сумка']
# []
# []
# ['арахис']
# ['раскраска']
# ['соединитель']
# ['лампа']
# ['ботинки']
# ['пальто']
# ['кольцо']
# ['гирлянд']
# []
# ['штаны']
# ['конфеты']
# ['хлеб']
# ['полировальник']
# []
# ['зажим']
# []
# ['футболка']
# ['тетрадь']
# []
# []
# ['контейнер']
# ['масло']
# ['глушитель']
# ['платье']
# []
# []
# ['йогурт']
# []
# []
# []
# ['патчи']
# []
# ['уксус']
# []
# []
# []
# []
# ['плитка']
# ['гренки']
# ['напиток']
# []
# ['батончик']
# ['болт']
# []
# ['носки']
# ['сливки']
# ['шуруп']
# ['рамка']
# []
# []
# ['пельмени']
# ['пинцет']
# ['ножницы']
# ['блины']
# ['корм']
# []
# ['трусы']
# ['конфеты']
# []
# ['скатерть']
# []
# []
# ['ремень']
# ['сигареты']
# ['плавки']
# ['саморез']
# []
# ['пленка']
# ['футболка']
# ['печенье']
# ['свечи']
# ['кольцо']
# ['кофе']
# []
# ['рюкзак']
# ['футболка']
# ['пельмени']
# []
# ['ботинки']
# ['печенье']
# ['купальник']
# ['макароны']
# []
# []
# ['сыр']
# ['болт']
# ['вода']
# ['шуруп']
# []
# ['рулетка']
# ['сок']
# ['футболка']
# []
# ['губка']
# ['скотч']
# []
# ['яйцо']
# ['аккумулятор']
# []
# ['масло']
# ['носки']
# ['пальто']
# []
# ['удлинитель']
# ['батон']
# ['саморез']
# []
# []
# ['бумага']
# ['футболка']
# ['освежитель']
# ['напиток']
# ['саморез']
# ['заклепочник']
# []
# ['молоко']
# ['кефир']
# ['рис']
# ['пальто']
# ['футболка']
# ['шуруп']
# ['трусы']
# []
# []
# ['тетрадь']
# ['сетильник']
# ['сметана']
# ['футболка']
# ['напиток']
# ['спрей']
# ['велосипед']
# ['шуруп']
# []
# ['кружка']
# ['шорты']
# ['футболка']
# ['майонез']
# []
# ['сапоги']
# []
# []
# []
# ['печенье']
# ['фильтр']
# ['подушечки']
# []
# ['корм']
# ['творог']
# ['лимонад']
# []
# []
# ['лампа']
# ['гель']
# ['гель']
# ['масло']
# ['молоток']
# ['футболка']
# []
# []
# ['футболка']
# ['шапка']
# ['туфли']
# []
# []
# ['тетрадь']
# []
# ['кофе']
# []
# ['соль']
# []
# ['пряники']
# ['ошейник']
# ['кофе']
# ['рис']
# ['маска']
# []
# []
# []
# ['контейнер']
# ['водолазка']
# ['батончик']
# ['попкорн']
# []
# []
# ['муфта']
# ['косичка']
# []
# ['мозаика']
# []
# ['кеды']
# ['толстовка']
# ['приправа']
# []
# ['велосипед']
# ['кольцо']
# ['пакет']
# []
# ['клей']
# ['майонез']
# ['ботинки']
# ['мороженое']
# []
# ['футболка']
# ['кольцо']
# []
# []
# ['пакеты']
# ['шапка']
# ['штуцер']
# []
# []
# ['биточки']
# ['термобрашинг']
# ['губка']
# ['пиво']
# ['сыворотка']
# ['зажигалки']
# []
# ['футболка']
# ['сухарики']
# ['корм']
# ['мыло']
# []
# ['сосиски']
# ['болт']
# []
# []
# ['ковер']
# []
# ['болт']
# ['болт']
# ['удлинитель']
# ['заглушка']
# ['альбом']
# []
# ['напиток']
# []
# []
# ['вода']
# ['сайра']
# []
# ['футболка']
# []
# ['гренки']
# []
# ['босоножки']
# ['фильтр']
# ['футболка']
# ['подводка']
# ['реле']
# []
# ['страховка']
# ['печенье']
# ['трусы']
# ['болт']
# []
# []
# []
# ['футболка']
# ['кукуруза']
# ['жидкость']
# []
# []
# ['футболка']
# ['сок']
# []
# ['рулетка']
# ['значок']
# []
# ['молоко']
# []
# []
# ['икра']
# []
# []
# ['футболка']
# ['гирлянда']
# ['костюм']
# ['элемент', '']
# ['жевательная']
# []
# ['дезодорант']
# ['выключатель']
# ['ошейник']
# ['килька']
# ['коктейль']
# ['свеча']
# ['хлебцы']
# []
# []
# []
# ['сахар']
# ['конфеты']
# ['пельмени']
# ['носки']
# ['сцепление']
# ['шарф']
# ['приправа']
# ['паштет']
# ['батарейки']
# []
# []
# ['соус']
# ['ботинки']
# ['мороженое']
# ['майонез']
# []
# []
# ['кефир']
# ['футболка']
# []
# ['спрей']
# []
# ['батон']
# []
# ['билет']
# []
# ['перчатки']
# []
# ['скатерть']
# ['ракетка']
# ['жакет']
# []
# []
# ['шампунь']
# ['переключатель']
# []
# []
# []
# ['биточки']
# ['уголь']
# []
# ['краска']
# ['каша']
# ['булочки']
# ['батарейка']
# ['ремень']
# ['печень']
# []
# []
# []
# ['пельмени']
# ['крекер']
# []
# ['крючок']
# ['брюки']
# []
# []
# ['батончик']
# ['паста']
# []
# ['обувь']
# ['паста']
# ['табурет']
# ['боди']
# ['футболка']
# []
# []
# ['зубная']
# ['аскорбинка']
# ['нектар']
# ['линолеум']
# ['конфеты']
# ['напиток']
# ['подшипники']
# ['футболка']
# ['сироп']
# ['футболка']
# ['соус']
# ['мыло']
# ['закладки']
# ['пельмени']
# ['леска']
# ['платье']
# []
# ['ботинки']
# []
# []
# ['гирлянда']
# ['сыр']
# ['мука']
# []
# ['футболка']
# ['ведро']
# ['масло']
# ['комбинезон']
# ['футболка']
# []
# ['альбом']
# ['дезодорант']
# []
# ['футболка']
# ['штаны']
# ['футболка']
# ['кольцо']
# ['шорты']
# []
# []
# []
# ['патчи']
# ['футболка']
# ['чай']
# []
# []
# ['одеяло']
# []
# ['шорты']
# ['масло']
# ['крем']
# ['свитер']
# ['мясорубка']
# ['хлеб']
# ['айран']
# []
# ['шапка']
# []
# []
# []
# ['хлеб']
# ['резинка']
# ['сыр']
# ['изолента']
# ['труба']
# ['пряники']
# ['футболка']
# []
# ['маска']
# []
# []
# ['морс']
# []
# []
# []
# ['конфеты']
# []
# ['сельдь']
# []
# []
# ['пускатель']
# ['вино']
# []
# []
# ['обувь']
# []
# ['рубашка']
# ['гель']
# []
# ['пельмени']
# ['кран']
# ['мыло']
# []
# ['фигурка']
# []
# []
# []
# ['салфетки']
# ['зефир']
# []
# []
# ['сверло']
# []
# []
# []
# []
# ['линолеум']
# ['шприц']
# ['контейнер']
# ['куртка']
# ['бандаж']
# ['болт']
# ['фильтр']
# []
# ['сыр']
# ['кофе']
# []
# ['легинсы']
# ['кофе']
# ['водонагреватель']
# ['котлеты']
# ['масло']
# ['плинтус']
# ['соус']
# ['фильтр']
# ['эксцентрик']
# []
# ['пальто']
# ['салатник']
# ['шапочка']
# []
# ['поло']
# ['рулет']
# ['водка']
# ['ремень']
# []
# ['молоток']
# []
# []
# []
# ['выключатель']
# ['вода']
# ['перфоратор']
# []
# ['болт']
# []
# []
# ['муфта']
# ['фильтр']
# ['гель']
# []
# ['жидкость']
# ['брюки']
# ['альбом']
# ['сыр']
# ['руккола']
# ['паста']
# ['контейн']
# ['цепь']
# []
# ['семена']
# ['уголок']
# []
# []
# ['лампа']
# ['футболка']
# ['зефир']
# ['балетки']
# []
# ['футболка']
# []
# ['сахар']
# ['резинка']
# ['коврик']
# ['реле']
# ['футболка']
# ['творожок']
# ['пельмени']
# ['сумка']
# ['гель']
# ['бальзам']
# ['молоко']
# ['рукавица']
# ['пленка']
# []
# []
# []
# ['икра']
# ['скатерть']
# ['мороженое']
# ['спред']
# []
# ['куртка']
# ['напиток']
# ['ведро']
# []
# ['лампа']
# ['удобрение']
# []
# []
# ['лимонад']
# ['джеггинсы']
# []
# []
# ['прокладки']
# []
# ['лампа']
# ['форма']
# []
# []
# ['жакет']
# []
# []
# ['кольцо']
# ['перец']
# []
# ['саморез']
# []
# ['шампунь']
# ['биойогурт']
# ['саморез']
# []
# ['сметана']
# ['футболка']
# ['кольцо']
# ['кофе']
# ['датчик']
# ['стельки']
# ['футболка']
# []
# ['эмаль']
# ['носки']
# ['саморез']
# ['лимонад']
# []
# ['щетка']
# []
# []
# ['коньяк']
# []
# ['футболка']
# ['вода']
# []
# ['скатерть']
# []
# []
# []
# ['майонез']
# ['мелки']
# []
# []
# ['боди']
# []
# ['футболка']
# ['соус']
# []
# ['сыр']
# []
# ['ремень']
# ['скатерть']
# ['фиксатор']
# []
# ['конфеты']
# ['румяна']
# []
# ['соус']
# []
# ['раскраска']
# ['фильтр']
# ['светильник']
# []
# ['вода']
# ['напиток']
# ['футболка']
# ['контейнер']
# ['легинсы']
# []
# []
# []
# []
# ['помада']
# ['альбом']
# ['футболка']
# ['гель']
# ['печенье']
# []
# []
# []
# ['салфетки']
# []
# []
# ['виски']
# ['паста']
# ['круассаны']
# []
# ['гель']
# ['ошейник']
# ['яйцо']
# ['замок']
# ['болт']
# ['сухарики']
# []
# ['сумка']
# ['мороженое']
# []
# ['шуруп']
# ['карандаш']
# []
# ['сыр']
# []
# ['halls']
# ['леска']
# []
# ['цепь']
# ['йогурт']
# []
# ['шипы']
# []
# []
# ['трусы']
# ['пиво']
# ['раскраска']
# ['шуруп']
# []
# ['палочки']
# ['плавки']
# ['творог']
# ['сыр']
# []
# ['саморез']
# []
# []
# ['фильтр']
# ['футболка']
# []
# ['мыло']
# []
# ['футболка']
# ['перчатки']
# []
# []
# []
# ['брюки']
# ['карандаш']
# []
# ['сухарики']
# ['виски']
# []
# []
# []
# []
# ['альбом']
# []
# []
# ['будильник']
# []
# ['кекс']
# ['мыло']
# ['шоколад']
# ['коронка']
# []
# ['фильтр']
# []
# []
# []
# ['шоколад']
# ['гирлянда']
# ['футболка']
# []
# ['подшипник']
# ['пазлы']
# ['иглы']
# []
# ['бейсболка']
# ['майонез']
# ['футболка']
# ['зубная']
# ['икра']
# ['пальто']
# ['пластырь']
# []
# ['бальзам']
# []
# []
# ['контейнер']
# ['маска']
# ['маска']
# ['светильник']
# ['кольцо']
# ['кольцо']
# ['смартфон']
# ['скумбрия']
# ['салфетки']
# ['антисептик']
# ['болт']
# []
# []
# []
# ['коврик']
# ['саморез']
# ['выключатель']
# ['шоколад']
# ['футболка']
# []
# []
# ['футболка']
# ['ботинки']
# []
# ['ковш']
# []
# ['кольцо']
# []
# ['болт']
# ['футболка']
# []
# ['пиво']
# ['биойогурт']
# ['сыр']
# ['ремень']
# []
# ['напиток']
# ['шоколад']
# []
# ['футболка']
# ['фильтр']
# ['сырок']
# []
# []
# ['пиво']
# ['саморез']
# []
# []
# ['поильник']
# ['шампунь']
# []
# ['джинсы']
# ['грунтовка']
# ['лонгслив']
# ['икра']
# ['съемник']
# ['шоколад']
# ['носки']
# ['футболка']
# []
# []
# []
# []
# ['сыворотка']
# ['контейнер']
# []
# []
# ['икра']
# ['дрожжи']
# []
# ['дезодорант']
# ['значок']
# ['прописи']
# []
# []
# []
# []
# ['свитер']
# ['коврик']
# ['яйцо']
# ['гематоген']
# ['кукла']
# ['болт']
# ['грунт']
# []
# ['сливки']
# []
# []
# ['кофе']
# ['сок']
# []
# ['майка']
# ['одеяло']
# ['шуруп']
# []
# ['саморез']
# ['держатель']
# ['рюкзак']
# ['переключатель']
# []
# ['крышка']
# ['переходник']
# []
# ['молоко']
# []
# ['лопатки']
# []
# ['оливки']
# ['опрыскиватель']
# []
# ['изолента']
# ['сок']
# ['реле']
# []
# ['брюки']
# []
# ['ботинки']
# ['удлинитель']
# ['ветровка']
# ['обувь']
# []
# ['плитка']
# ['мелки']
# ['футболка']
# []
# ['шнур']
# ['молоток']
# ['мыло']
# ['пирожное']
# ['паста']
# ['сланцы']
# ['пиво']
# ['снеки']
# []
# []
# ['пюре']
# ['футболка']
# ['футболка']
# []
# ['футболка']
# []
# ['цепь']
# ['кукуруза']
# ['каша']
# ['грунт']
# ['плед']
# []
# []
# ['ошейник']
# ['сыр']
# ['контейнер']
# []
# ['крючок']
# ['сыр']
# ['носки']
# ['щетка']
# ['шапка']
# ['болт']
# ['шоколад']
# ['блейзер']
# ['футболка']
# []
# ['сок']
# ['испаритель']
# ['бюстгальтер']
# ['раскраска']
# ['яйцо']
# []
# ['зефир']
# ['жидкость']
# ['молоко']
# []
# ['футболка']
# ['гренки']
# []
# ['перчатки']
# ['молоток']
# []
# ['топ']
# []
# ['бандаж']
# []
# []
# ['ботинки']
# ['билет']
# ['ботинки']
# []
# ['футболка']
# ['мороженое']
# ['конфеты']
# []
# ['батончик']
# ['ремень']
# ['хомут']
# []
# ['салфетка']
# ['коврик']
# ['заглушка']
# ['резинка']
# ['колготки']
# ['ремень']
# ['ботинки']
# ['коктейль']
# []
# ['колгот']
# ['штуцер']
# []
# ['шампунь']
# ['мармелад']
# ['костюм']
# []
# ['водолазка']
# ['эмаль']
# ['стейк']
# ['смеситель']
# ['молоко']
# []
# []
# []
# []
# []
# ['батончик']
# []
# []
# ['кофе']
# ['джемпер']
# ['футболка']
# ['футболка']
# []
# ['айран']
# ['ботинки']
# ['пирожное']
# []
# ['напиток']
# ['сверло']
# ['пакеты']
# ['палочки']
# ['цукаты']
# ['замок']
# ['тампоны']
# ['грунтовка']
# ['джемпер']
# ['мазь']
# ['манжета']
# ['коврик']
# ['кофе']
# []
# []
# ['торт']
# ['скотч']
# ['угол']
# []
# ['молоко']
# ['мармелад']
# ['мыло']
# []
# ['рамка']
# []
# []
# []
# []
# []
# ['линолеум']
# []
# []
# []
# ['миксер']
# []
# ['наклейка']
# ['цепь']
# []
# ['пряники']
# []
# ['сыр']
# []
# ['напиток']
# ['йогурт']
# ['форма']
# []
# ['мазь']
# ['бальзам']
# ['эмаль']
# ['пельмени']
# ['болт']
# ['ремень']
# ['коврик']
# ['карандаш']
# []
# []
# ['ботинки']
# ['ручка']
# ['ботинки']
# []
# ['клей']
# ['брюки']
# ['колбаса']
# []
# []
# ['пряники']
# ['чистящее']
# ['футболка']
# ['толстовка']
# ['каша']
# ['ручка']
# []
# []
# ['футболка']
# ['футболка']
# ['саморез']
# ['ботинки']
# ['вода']
# []
# ['кружка']
# ['скотч']
# []
# ['салфетки']
# ['джинсы']
# []
# ['молоко']
# ['футболка']
# ['саморез']
# []
# []
# ['кольцо']
# ['скотч']
# []
# ['футболка']
# ['держатель']
# ['сыр']
# []
# ['футболка']
# ['болт']
# ['шампунь']
# ['футболка']
# ['масло']
# ['мармелад']
# ['кроссовки']
# []
# ['футболка']
# []
# []
# ['сверло']
# ['зеркало']
# []
# []
# []
# ['батончик']
# ['шайба']
# ['брюки']
# ['напиток']
# []
# ['толстовка']
# ['футболка']
# []
# []
# ['ремень']
# ['масло']
# ['зажим']
# []
# ['трусы']
# []
# []
# ['платье']
# ['вино']
# ['кассеты']
# ['каша']
# ['акустика']
# []
# []
# ['муфта']
# ['контейнер']
# []
# ['шайба']
# ['сыр']
# ['кукуруза']
# ['удлинитель']
# ['лакомство']
# ['сачок']
# ['водка']
# ['порошок']
# ['чебуреки']
# []
# []
# ['печенье']
# []
# ['мороженое']
# ['клей']
# []
# []
# ['чай']
# []
# ['футболка']
# ['краска']
# []
# ['карабин']
# ['пальто']
# []
# []
# ['сыр']
# []
# ['фильтр']
# ['петля']
# ['штаны']
# []
# []
# ['ошейник']
# ['рубашка']
# ['напиток']
# ['леденцы']
# []
# []
# ['сосиски']
# ['раскраска']
# ['перчатки']
# ['конфеты']
# []
# ['саморез']
# ['болт']
# ['футболка']
# []
# []
# ['ботинки']
# []
# ['кольцо']
# ['ручка']
# ['батарейки']
# ['юбка']
# ['пряники']
# ['биойогурт']
# ['колодка']
# []
# ['ветчина']
# ['пуловер']
# ['шнур']
# []
# ['ботинки']
# []
# []
# []
# []
# ['грунт']
# []
# ['контейнер']
# ['торт']
# ['рюкзак']
# ['футболка']
# []
# []
# ['футболка']
# ['сухарики']
# ['мыло']
# ['масло']
# ['сыр']
# []
# ['шампунь']
# ['торт']
# ['краситель']
# ['щетка']
# ['гематоген']
# ['шампунь']
# ['зефир']
# ['сок']
# ['сельдь']
# ['монитор']
# ['болт']
# ['пена']
# []
# ['ошейник']
# ['грунт']
# []
# []
# ['коврик']
# ['куртка']
# ['водолазка']
# ['кофе']
# []
# []
# ['скетчбук']
# []
# ['легинсы']
# ['мороженое']
# ['икра']
# ['платье']
# []
# ['краска']
# ['закуска']
# []
# ['опора']
# []
# []
# []
# []
# ['пиво']
# ['реле']
# ['', 'доска']
# ['футболка']
# ['фильтр']
# ['ящик']
# ['футболка']
# ['покрывало']
# ['сухари']
# ['футболка']
# ['краска']
# []
# ['колбаска']
# ['стейк']
# []
# []
# []
# ['напиток']
# ['рулетка']
# ['футболка']
# ['вино']
# ['полироль']
# ['ободок']
# ['топ']
# []
# ['печенье']
# ['контейнер']
# ['платье']
# ['мыло']
# ['уши']
# ['фломастеры']
# []
# ['ободок']
# []
# ['поло']
# []
# []
# ['краска']
# ['футболка']
# ['соус']
# ['фуфайка']
# ['контейнер']
# ['кроссовки']
# ['футболка']
# ['кофе']
# ['футболка']
# []
# ['тапочки']
# []
# ['ботинки']
# ['конфеты']
# ['яйцо']
# ['соломка']
# ['гель']
# ['вода']
# []
# ['зефир']
# []
# []
# []
# ['футболка']
# ['футболка']
# ['футболка']
# ['снуд']
# []
# ['камера']
# []
# ['драже']
# ['сметана']
# ['шоколад']
# []
# ['зеркало']
# []
# []
# ['легинсы']
# []
# ['печенье']
# ['шоколад']
# []
# ['салфетки']
# ['футболка']
# []
# ['платье']
# []
# ['сыр']
# ['шприц']
# []
# ['губка']
# []
# ['саморез']
# ['жилет']
# []
# ['зеркало']
# ['кардиган']
# ['сырок']
# ['пальто']
# ['пюре']
# ['туфли']
# ['форма']
# []
# ['форма']
# ['кольцо']
# []
# ['водолазка']
# ['саморез']
# ['носки']
# []
# ['пюре']
# []
# ['крышка']
# ['футболка']
# ['куртка']
# ['футболка']
# ['драже']
# ['футболка']
# []
# ['обложка']
# ['драже']
# ['футболка']
# []
# ['ковш']
# []
# []
# []
# ['угольник']
# ['прокладки']
# []
# ['штуцер']
# ['крючки']
# []
# []
# ['футболка']
# ['кроссовки']
# ['платье']
# []
# []
# ['футболка']
# []
# ['напиток']
# ['трусики']
# ['ручка']
# ['сумка']
# ['футболка']
# ['книга']
# ['штуцер']
# ['масло']
# ['икра']
# ['элемент', '']
# ['заглушка']
# []
# ['кольцо']
# ['бумага']
# ['скатерть']
# []
# ['замок']
# ['сыр']
# []
# ['нектар']
# []
# ['напиток']
# ['батон']
# []
# ['краска']
# ['леденцы']
# ['джемпер']
# []
# []
# []
# ['кофе']
# []
# ['вино']
# []
# []
# ['конфеты']
# ['ананасы']
# ['шоколад']
# ['мешок']
# ['платье']
# ['пальто']
# ['болт']
# ['болт']
# ['резинка']
# ['сосиски']
# ['платье']
# []
# []
# ['носки']
# ['футболка']
# ['насадка']
# ['сорочка']
# ['батон']
# []
# ['футболка']
# ['фаленопсис']
# ['соус']
# ['покрышка']
# ['яйцо']
# ['мешки']
# ['саморез']
# ['футболка']
# []
# ['вода']
# []
# []
# []
# ['соус']
# ['антиперспирант']
# ['альбом']
# []
# []
# ['ножницы']
# ['закладки']
# []
# ['футболка']
# ['контейнер']
# ['футболка']
# []
# ['футболка']
# ['муфта']
# []
# ['игрушка']
# ['гель']
# ['боди']
# []
# ['икра']
# ['колготки']
# ['болт']
# ['футболка']
# ['пиво']
# ['ботинки']
# []
# []
# ['шампанское']
# ['кольцо']
# []
# ['маркер']
# ['корм']
# []
# ['вино']
# ['совок']
# []
# []
# []
# ['масло']
# ['куртка']
# ['пюре']
# ['спот']
# []
# ['lips']
# ['сушки']
# ['уголь']
# ['кефир']
# []
# []
# []
# ['halls']
# []
# ['обувь']
# ['попкорн']
# ['коньяк']
# ['футболка']
# []
# ['фильтр']
# ['чай']
# ['зефир']
# []
# ['краска']
# ['саморез']
# ['сигареты']
# ['хлебцы']
# ['коврик']
# ['подушечки']
# ['маркер']
# ['коврик']
# ['слипоны']
# ['чипсы']
# []
# ['сыр']
# []
# ['молоко']
# ['рубашка']
# ['водолазка']
# ['конфеты']
# ['огурцы']
# []
# []
# ['мармелад']
# []
# ['килька']
# ['колбаса']
# ['фильтр']
# ['ремень']
# ['молоко']
# ['напиток']
# []
# ['футболка']
# ['полотенце']
# ['футболка']
# ['кофе']
# []
# ['гренки']
# ['папка']
# ['футболка']
# ['коляска']
# []
# ['толстовка']
# ['леденцы']
# ['герметик']
# []
# ['яйцо']
# ['коврик']
# ['легинсы']
# ['изолента']
# ['леска']
# []
# ['мушка']
# ['водка']
# ['коктейль']
# ['ароматизатор']
# ['пельмени']
# ['вода']
# ['зонт']
# []
# ['мармелад']
# ['крем']
# []
# ['носки']
# ['перчатки']
# ['покрышка']
# ['конфеты']
# ['сайра']
# ['жевательная']
# ['попкорн']
# []
# ['коньяк']
# ['тушь']
# []
# ['футболка']
# ['кофе']
# ['герметик']
# ['совок']
# []
# ['хомуты']
# []
# ['масло']
# ['фонарь']
# ['замок']
# ['шоколад']
# ['яйцо']
# ['мармелад']
# []
# ['батончик']
# ['футболка']
# []
# ['бедро']
# []
# []
# []
# []
# []
# ['бюстгальтер']
# ['тетрадь']
# []
# ['ремень']
# ['растворитель']
# []
# ['муфта']
# ['промывка']
# ['покрывало']
# ['шоколад']
# ['каша']
# ['ремень']
# ['футболка']
# []
# []
# ['клей']
# ['саморез']
# ['болт']
# ['вода']
# ['коньяк']
# ['болт']
# []
# ['датчик']
# ['спрей']
# ['мокасины']
# []
# []
# ['футболка']
# ['кольцо']
# []
# []
# ['спрей']
# ['футболка']
# ['футболка']
# ['томат']
# ['сковорода']
# ['толстовка']
# ['вода']
# []
# ['водка']
# []
# []
# ['велопокрышка']
# []
# []
# []
# ['кольцо']
# ['трусы']
# []
# ['термопленка']
# ['саморез']
# ['мыло']
# ['чай']
# ['переходник']
# []
# ['сайра']
# []
# ['футболка']
# ['брюки']
# ['пиво']
# ['гель']
# ['пиво']
# []
# []
# ['боди']
# []
# ['жевательная']
# ['трусы']
# ['куртка']
# ['фильтр']
# ['пакет']
# ['футболка']
# ['линза']
# []
# ['футболка']
# ['бумага']
# ['болт']
# ['зажигалка']
# ['коктейль']
# ['бальзам']
# ['вода']
# ['батон']
# ['кисть']
# ['салфетки']
# ['ботинки']
# []
# ['горелка']
# ['футболка']
# []
# []
# ['фреза']
# ['замок']
# ['футболка']
# ['шорты']
# []
# []
# ['йогурт']
# ['пиво']
# ['лимонад']
# ['соус']
# []
# ['аккумулятор']
# ['саморез']
# ['клеенка']
# ['альбом']
# ['колготки']
# ['шпатлевка']
# []
# ['краска']
# ['нектар']
# []
# []
# ['футболка']
# ['фоторамка']
# ['футболка']
# ['кольцо']
# ['заглушка']
# ['водка']
# []
# ['рубашка']
# []
# ['сок']
# []
# ['шоколад']
# ['зефир']
# ['болт']
# []
# ['бальзам']
# ['кофта']
# ['масло']
# ['сок']
# ['пиво']
# []
# ['рюкзак']
# ['кукуруза']
# ['попкорн']
# []
# ['удлинитель']
# ['сыр']
# ['кольцо']
# ['футболка']
# ['тест']
# []
# ['фуфайка']
# []
# ['краска']
# ['фильтр']
# ['значок']
# ['батончик']
# ['носки']
# ['лапша']
# ['шницель']
# ['икра']
# ['кисть']
# ['серьги']
# ['кофе']
# ['выключатель']
# ['полироль']
# ['батон']
# []
# ['сок']
# ['прокладки']
# ['ботинки']
# []
# ['мыло']
# ['светильник']
# ['конфеты']
# ['пальто']
# ['табурет']
# []
# []
# []
# ['этель']
# ['сыр']
# []
# ['болт']
# []
# ['вода']
# []
# ['гренки']
# ['зубная']
# ['табак']
# ['футболка']
# []
# []
# ['квас']
# []
# []
# ['перчатки']
# ['брюки']
# ['лимонад']
# ['соус']
# ['кофе']
# ['краска']
# ['дневник']
# ['паста']
# ['раскраска']
# ['брюки']
# []
# ['хачапури']
# ['толстовка']
# ['будильник']
# ['болт']
# ['значок']
# ['лимонад']
# []
# []
# ['перчатки']
# ['выключатель']
# ['ободок']
# ['футболка']
# []
# ['арахис']
# []
# []
# []
# ['печенье']
# ['кружка']
# ['крупа']
# ['пена']
# ['паста']
# ['ботинки']
# ['гель']
# []
# []
# []
# []
# []
# ['саморез']
# []
# ['сыр']
# []
# []
# ['шайба']
# []
# ['лимонад']
# ['мозаика']
# ['отвертка']
# ['скатерть']
# []
# ['сыр']
# ['ботинки']
# ['ремень']
# []
# []
# ['розетка']
# ['шуруп']
# ['бальзам']
# ['сыр']
# ['футболка']
# ['палочки']
# ['бифштекс']
# ['гренки']
# ['тряпка']
# ['футболка']
# ['соус']
# ['накладки']
# ['пряники']
# []
# []
# ['ботинки']
# []
# []
# ['мыло']
# ['рюкзак']
# []
# ['сверло']
# ['крем']
# ['футболка']
# ['рис']
# ['десерт']
# ['опора']
# ['пицца']
# []
# []
# ['хлеб']
# ['датчик']
# ['свитшот']
# []
# ['каша']
# ['креветки']
# ['биойогурт']
# ['джемпер']
# ['футболка']
# ['элемент']
# []
# ['футболка']
# ['карта', '']
# []
# ['ходунки']
# ['спрей']
# ['бумага']
# ['футболка']
# []
# ['корм']
# []
# ['мороженое']
# []
# ['футболка']
# ['скатерть']
# []
# []
# ['пюре']
# ['бумага']
# []
# ['фильтр']
# []
# ['контейнер']
# ['щипцы']
# ['леденцы']
# ['тортовница']
# ['батон']
# ['мазь']
# ['тренажер']
# ['заглушка']
# ['угольник']
# []
# []
# ['шуруп']
# ['ремень']
# ['упор']
# []
# ['контейнер']
# []
# ['пиво']
# ['спальник']
# ['хомут']
# []
# []
# []
# []
# ['рубашки']
# ['болт']
# ['пузыри']
# ['пряжа']
# ['мыло']
# ['шланг']
# ['соус']
# ['адаптер']
# ['легинсы']
# ['пена']
# ['пиво']
# ['болт']
# ['футболка']
# ['удлинитель']
# ['баклажаны']
# []
# ['рюкзак']
# ['лейкопластырь']
# ['болт']
# ['болт']
# ['брюки']
# []
# ['мука']
# ['рыба']
# ['клей']
# []
# []
# ['конфеты']
# ['пельмени']
# ['игра']
# []
# ['салфетки']
# ['болт']
# ['болт']
# []
# []
# ['ряженка']
# ['бумага']
# ['кукуруза']
# []
# ['розетка']
# []
# ['штуцер']
# ['шампунь']
# ['пальто']
# ['кисель']
# []
# ['хлебцы']
# ['колготки']
# ['творог']
# ['морс']
# []
# []
# ['икра']
# []
# ['корм']
# []
# ['горелка']
# ['сок']
# ['фрезер']
# ['бассейн']
# ['картофель']
# []
# []
# ['удлинитель']
# []
# []
# ['ботинки']
# ['сахар']
# []
# []
# ['сандалии']
# []
# []
# []
# []
# []
# []
# []
# ['футболка']
# []
# []
# ['соломка']
# ['саморез']
# ['лампа']
# ['трусы']
# ['водолазка']
# []
# ['трусы']
# ['заглушка']
# ['футболка']
# ['водка']
# ['замок']
# ['футболка']
# []
# ['батончик']
# ['опора']
# ['ветровка']
# []
# ['кроссовки']
# []
# ['крекер']
# ['кекс']
# ['часы']
# ['батончик']
# ['уксус']
# []
# []
# ['коктейль']
# ['лак']
# ['сухари']
# ['молоко']
# ['щечки']
# ['контейнер']
# []
# []
# ['ручка']
# ['обувь']
# []
# []
# ['мороженое']
# ['легинсы']
# ['творог']
# ['футболка']
# ['переходник']
# []
# ['кисель']
# ['сумка']
# []
# ['помидоры']
# []
# []
# []
# []
# ['футболка']
# ['сырок']
# ['покрывало']
# []
# ['сумка']
# []
# []
# ['шоколад']
# ['брюки']
# ['футболка']
# ['перчатки']
# []
# []
# []
# ['присыпка']
# ['фильтр']
# []
# ['брюки']
# ['вода']
# []
# ['саморез']
# []
# ['чай']
# ['рис']
# ['бита']
# ['расческа']
# ['топ']
# ['приправа']
# []
# ['линза']
# ['вода']
# ['конфеты']
# ['элемент', '']
# ['чай']
# ['футболка']
# []
# []
# ['икра']
# ['выключатель']
# ['мыло']
# []
# []
# []
# ['кисть']
# ['хлеб']
# []
# []
# ['туфли']
# []
# ['скумбрия']
# []
# ['шампунь']
# ['держатель']
# ['кефир']
# ['тетрадь']
# ['кисть']
# ['хлебцы']
# ['сыр']
# []
# []
# ['лапша']
# ['сланцы']
# ['вода']
# ['футболка']
# []
# ['контейнер']
# []
# ['футболка']
# []
# ['гамбургер']
# ['батончик']
# ['саморез']
# []
# ['семечки']
# ['хлеб']
# ['кофе']
# ['вода']
# ['грунт']
# ['чипсы']
# []
# ['болт']
# ['муфта']
# ['напиток']
# ['кольцо']
# []
# []
# []
# []
# ['саморез']
# []
# ['полироль']
# []
# []
# ['шумоизоляция']
# ['шампунь']
# []
# ['скобы']
# ['салфетка']
# []
# []
# []
# ['лонгслив']
# []
# []
# ['ботинки']
# ['болт']
# ['нож']
# ['футболка']
# ['контейнер']
# ['пиво']
# ['футболка']
# []
# ['трусы']
# ['колбаса']
# []
# []
# ['сосиски']
# ['наполнитель']
# ['саморез']
# ['зефир']
# ['саморез']
# []
# []
# ['ножницы']
# []
# ['ковш']
# ['пиво']
# []
# []
# ['мыло']
# ['сухарики']
# ['шлем']
# ['пиво']
# ['каша']
# ['крем']
# []
# ['футболка']
# []
# ['туфли']
# ['водка']
# []
# ['приправа']
# []
# ['шампунь']
# ['лак']
# ['салфетки']
# ['пиво']
# ['конфеты']
# []
# ['джинсы']
# ['пельмени']
# []
# ['брюки']
# ['плитка']
# []
# ['макароны']
# ['ветровка']
# ['ложка']
# ['ремень']
# ['коньяк']
# []
# ['губки']
# []
# []
# ['резинка']
# []
# ['лимонад']
# ['пельмени']
# []
# ['чипсы']
# ['коктейль']
# []
# ['рубашка']
# ['паста']
# ['пряник']
# []
# []
# ['мыло']
# ['печенье']
# []
# ['футболка']
# ['лапша']
# []
# []
# []
# ['кондиционер']
# []
# ['ролик']
# ['кпб']
# ['украшение']
# ['журнал']
# ['сардельки']
# []
# []
# ['прокладки']
# []
# []
# []
# ['вода']
# ['водка']
# []
# ['розетка']
# []
# []
# []
# []
# []
# []
# []
# ['крем']
# []
# ['коврик']
# []
# []
# ['контейнер']
# []
# ['пуловер']
# ['покрывало']
# ['гирлянда']
# ['карандаши']
# []
# []
# []
# []
# ['сыр']
# ['сальник']
# ['кольцо']
# []
# ['носки']
# ['муфта']
# []
# ['футболка']
# ['виски']
# ['салфетка']
# ['батарейка']
# ['сыр']
# ['ботинки']
# ['юбка']
# ['пятновыводитель']
# ['шайба']
# ['футболка']
# ['брюки']
# []
# ['соус']
# []
# ['полуботинки']
# ['спрей']
# ['кофе']
# ['свеча']
# []
# ['машинка']
# []
# []
# ['сетка']
# []
# ['масло']
# ['муфта']
# ['лампа']
# ['футболка']
# ['ремень']
# ['футболка']
# ['свитшот']
# ['рис']
# ['радиатор']
# []
# []
# ['мармелад']
# ['саморез']
# ['напиток']
# ['плитка']
# ['саморез']
# []
# ['платье']
# ['футболка']
# ['вино']
# ['опора']
# []
# ['патчи']
# ['майка']
# ['муфта']
# ['болт']
# []
# ['водка']
# ['зеркало']
# ['книга']
# ['пряники']
# ['пиво']
# ['рюкзак']
# []
# ['саморез']
# ['бульмени']
# ['одеяло']
# ['пельмени']
# []
# ['носки']
# ['макароны']
# []
# []
# ['футболка']
# ['биточки']
# []
# ['ветровка']
# []
# ['соединитель']
# ['краска']
# ['напиток']
# []
# ['болт']
# ['конфеты']
# ['кофе']
# ['кабель']
# []
# ['заглушка']
# ['пульт']
# []
# ['ботинки']
# ['батон']
# ['футболка']
# ['сыр']
# ['футболка']
# ['краситель']
# ['пиво']
# ['грузди']
# ['булочка']
# ['вино']
# ['попкорн']
# []
# ['саморез']
# ['футболка']
# []
# ['кастрюля']
# ['кофе']
# ['футболка']
# ['сырок']
# ['масло']
# ['хлебцы']
# ['рис']
# []
# []
# []
# []
# ['джинсы']
# []
# ['фильтр']
# ['рулетики']
# ['мармелад']
# ['ароматизатор']
# ['носки']
# ['молоко']
# ['жевательная']
# ['пюре']
# ['саморез']
# ['комбинезон']
# []
# []
# ['саморез']
# ['муфта']
# []
# []
# ['мыло']
# []
# ['йогурт']
# ['фильтр']
# []
# []
# []
# ['вода']
# ['блузка']
# ['кольцо']
# []
# ['панель']
# ['калькулятор']
# ['скумбрия']
# ['корм']
# ['сметана']
# []
# []
# ['молоко']
# ['творожок']
# []
# []
# []
# ['болт']
# []
# []
# ['печенье']
# []
# ['йогурт']
# ['вода']
# ['заглушка']
# ['поводок']
# []
# ['кольцо']
# []
# ['сухарики']
# []
# ['туфли']
# ['футболка']
# ['пальто']
# []
# ['ящик']
# ['йогурт']
# ['крем']
# ['гирлянда']
# ['сок']
# []
# []
# ['печенье']
# []
# ['сметана']
# ['печенье']
# ['вода']
# ['смеситель']
# ['вино']
# ['кетчуп']
# []
# ['пленка']
# ['пуговица']
# ['кукуруза']
# ['кисть']
# []
# ['перчатки']
# ['футболка']
# ['швабра']
# []
# []
# []
# ['боди']
# ['носки']
# ['сверло']
# ['джинсы']
# []
# ['футболка']
# ['футболка']
# []
# ['вода']
# ['водка']
# ['сыр']
# ['салфетки']
# []
# ['напиток']
# ['мороженое']
# ['зеркало']
# []
# ['форма']
# ['напиток']
# ['десерт']
# ['уголок']
# []
# ['табак']
# ['соединитель']
# []
# []
# ['сыр']
# ['реле']
# ['вода']
# []
# []
# []
# []
# []
# []
# ['кеды']
# []
# ['пропитка']
# []
# ['обложка']
# ['ароматизатор']
# ['сумка']
# []
# []
# []
# ['семечки']
# ['паштет']
# ['ботинки']
# ['салфет']
# ['фильтр']
# []
# ['сельдь']
# ['футболка']
# ['йогурт']
# ['фильтр']
# ['молоко']
# ['перец']
# ['муфта']
# ['гель']
# ['розетка']
# ['пельмени']
# []
# []
# ['пирожное']
# []
# ['удлинитель']
# ['штуцер']
# ['футболка']
# ['ремень']
# ['опрыскиватель']
# ['шуруп']
# ['кукуруза']
# ['кувшин']
# []
# ['зефир']
# ['саморез']
# []
# ['сыр']
# ['пакеты']
# ['футболка']
# []
# ['сироп']
# []
# []
# ['торт']
# ['водка']
# ['саморез']
# ['кофе']
# ['кольцо']
# ['майонез']
# []
# ['крем']
# ['колготки']
# ['ананасы']
# ['переключатель']
# ['фильтр']
# []
# ['блесна']
# ['рис']
# ['футболка']
# ['вода']
# ['клей']
# []
# ['творог']
# ['контейнер']
# []
# ['гель']
# ['наклейки']
# ['зажигалка']
# []
# ['пиво']
# ['худи']
# ['шапка']
# ['перекись', '']
# ['фаленопсис']
# ['блокнот']
# ['драже']
# []
# []
# ['шоколад']
# []
# ['пальто']
# []
# ['масло']
# ['рубашка']
# ['печенье']
# ['фреза']
# ['лампочка']
# []
# []
# ['крем']
# ['штопор']
# ['футболка']
# []
# ['сметана']
# []
# ['плата']
# ['рамка']
# ['напиток']
# ['наконечники']
# ['шоколад']
# ['опора']

# %%
brand = submission_brand(test_df)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9880\1096705545.py:6: DeprecationWarning: Call to deprecated `word_vec` (Use get_vector instead).
#   dataset = tokenss.apply(lambda x: w2v_model.wv.word_vec(x))

# %%
sub_df["good"] = good
sub_df["brand"] = brand

# %%
sub_df.to_csv("submission_all.csv")

# %%
def create_submit(row):
    good = []

    for i in row:
        try:
            word_array = w2v_model.wv.word_vec(i)
            dataset = pd.DataFrame(word_array.reshape((1, 300)))
            pred = model_good.predict(dataset)
            if pred[0][0] == "B-GOOD":
                good.append(i)
        except Exception as e:
            pass
    
    return ''.join(good)

# %%
def create_submit_brand(row):
    brand = []

    for i in row:
        try:
            word_array = w2v_model.wv.word_vec(i)
            dataset = pd.DataFrame(word_array.reshape((1, 300)))
            pred = model_brand.predict(dataset)
            if pred[0][0] == "B-BRAND":
                brand.append(i)
        except Exception as e:
            pass
    
    return ''.join(brand)

# %%
test_df["good"] = test_df["tokens"].apply(create_submit)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9880\373475702.py:6: DeprecationWarning: Call to deprecated `word_vec` (Use get_vector instead).
#   word_array = w2v_model.wv.word_vec(i)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 test_df["good"] = test_df["tokens"].apply(create_submit)
#
# File c:\Users\Admin\AppData\Local\pypoetry\Cache\virtualenvs\nlp-in-practice-Y7YXEI1I-py3.9\lib\site-packages\pandas\core\series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# -> 4630     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File c:\Users\Admin\AppData\Local\pypoetry\Cache\virtualenvs\nlp-in-practice-Y7YXEI1I-py3.9\lib\site-packages\pandas\core\apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# File c:\Users\Admin\AppData\Local\pypoetry\Cache\virtualenvs\nlp-in-practice-Y7YXEI1I-py3.9\lib\site-packages\pandas\core\apply.py:1076, in SeriesApply.apply_standard(self)
#    1074     else:
#    1075         values = obj.astype(object)._values
# -> 1076         mapped = lib.map_infer(
#    1077             values,
#    1078             f,
#    1079             convert=self.convert_dtype,
#    1080         )
#    1082 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1083     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1084     #  See also GH#25959 regarding EA support
#    1085     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\Admin\AppData\Local\pypoetry\Cache\virtualenvs\nlp-in-practice-Y7YXEI1I-py3.9\lib\site-packages\pandas\_libs\lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# Cell In[46], line 8, in create_submit(row)
#       6 word_array = w2v_model.wv.word_vec(i)
#       7 dataset = pd.DataFrame(word_array.reshape((1, 300)))
# ----> 8 pred = model_good.predict(dataset)
#       9 if pred[0][0] == "B-GOOD":
#      10     good.append(i)
#
# File c:\Users\Admin\AppData\Local\pypoetry\Cache\virtualenvs\nlp-in-practice-Y7YXEI1I-py3.9\lib\site-packages\catboost\core.py:5187, in CatBoostClassifier.predict(self, data, prediction_type, ntree_start, ntree_end, thread_count, verbose, task_type)
#    5136 def predict(self, data, prediction_type='Class', ntree_start=0, ntree_end=0, thread_count=-1, verbose=None, task_type="CPU"):
#    5137     """
#    5138     Predict with data.
#    5139
#    (...)
#    5185               with log probability for every class for each object.
#    5186     """
# -> 5187     return self._predict(data, prediction_type, ntree_start, ntree_end, thread_count, verbose, 'predict', task_type)
#
# File c:\Users\Admin\AppData\Local\pypoetry\Cache\virtualenvs\nlp-in-practice-Y7YXEI1I-py3.9\lib\site-packages\catboost\core.py:2543, in CatBoost._predict(self, data, prediction_type, ntree_start, ntree_end, thread_count, verbose, parent_method_name, task_type)
#    2541 if verbose is None:
#    2542     verbose = False
# -> 2543 data, data_is_single_object = self._process_predict_input_data(data, parent_method_name, thread_count)
#    2544 self._validate_prediction_type(prediction_type)
#    2546 predictions = self._base_predict(data, prediction_type, ntree_start, ntree_end, thread_count, verbose, task_type)
#
# File c:\Users\Admin\AppData\Local\pypoetry\Cache\virtualenvs\nlp-in-practice-Y7YXEI1I-py3.9\lib\site-packages\catboost\core.py:2523, in CatBoost._process_predict_input_data(self, data, parent_method_name, thread_count, label)
#    2521 is_single_object = _is_data_single_object(data)
#    2522 if not isinstance(data, Pool):
# -> 2523     data = Pool(
#    2524         data=[data] if is_single_object else data,
#    2525         label=label,
#    2526         cat_features=self._get_cat_feature_indices() if not isinstance(data, FeaturesData) else None,
#    2527         text_features=self._get_text_feature_indices() if not isinstance(data, FeaturesData) else None,
#    2528         embedding_features=self._get_embedding_feature_indices() if not isinstance(data, FeaturesData) else None,
#    2529         thread_count=thread_count
#    2530     )
#    2531 return data, is_single_object
#
# File c:\Users\Admin\AppData\Local\pypoetry\Cache\virtualenvs\nlp-in-practice-Y7YXEI1I-py3.9\lib\site-packages\catboost\core.py:792, in Pool.__init__(self, data, label, cat_features, text_features, embedding_features, embedding_features_data, column_description, pairs, delimiter, has_header, ignore_csv_quoting, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count, log_cout, log_cerr)
#     786         if isinstance(feature_names, PATH_TYPES):
#     787             raise CatBoostError(
#     788                 "feature_names must be None or have non-string type when the pool is created from "
#     789                 "python objects."
#     790             )
# --> 792         self._init(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
#     793                    group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count)
#     794 super(Pool, self).__init__()
#
# File c:\Users\Admin\AppData\Local\pypoetry\Cache\virtualenvs\nlp-in-practice-Y7YXEI1I-py3.9\lib\site-packages\catboost\core.py:1419, in Pool._init(self, data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count)
#    1417 if feature_tags is not None:
#    1418     feature_tags = self._check_transform_tags(feature_tags, feature_names)
# -> 1419 self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
#    1420                 group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count)
#
# File _catboost.pyx:3955, in _catboost._PoolBase._init_pool()
#
# File _catboost.pyx:4005, in _catboost._PoolBase._init_pool()
#
# File _catboost.pyx:3821, in _catboost._PoolBase._init_features_order_layout_pool()
#
# File _catboost.pyx:2729, in _catboost._set_features_order_data_pd_data_frame()
#
# File c:\Users\Admin\AppData\Local\pypoetry\Cache\virtualenvs\nlp-in-practice-Y7YXEI1I-py3.9\lib\site-packages\pandas\core\frame.py:1349, in DataFrame.items(self)
#    1347 if self.columns.is_unique and hasattr(self, "_item_cache"):
#    1348     for k in self.columns:
# -> 1349         yield k, self._get_item_cache(k)
#    1350 else:
#    1351     for i, k in enumerate(self.columns):
#
# KeyboardInterrupt:

# %%
test_df["brand"] = test_df["tokens"].apply(create_submit_brand)

# %%
test_df.info()

# %%
test_df

# %%
test_df.to_csv('br.csv')

# %%
sub_df['good'] = test_df["good"]

# %%
sub_df['brand'] = test_df["brand"]

# %%
sub_df.fillna('')

# %%
sub_df.to_csv("submission.csv")

# %%
s = w2v_model.wv.word_vec("штукатурка")
